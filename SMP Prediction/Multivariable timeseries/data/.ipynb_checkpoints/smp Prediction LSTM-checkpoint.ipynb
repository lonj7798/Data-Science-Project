# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional
from keras.optimizers import SGD
import math
from sklearn.metrics import mean_squared_error

# %%
def plot_predictions(test,predicted):
    plt.plot(test, color='red',label='SMP_mean')
    plt.plot(predicted, color='blue',label='Predicted SMP')
    plt.title('SMP_mean Prediction')
    plt.xlabel('Time')
    plt.ylabel('SMP_mean')
    plt.legend()
    plt.show()

def return_rmse(test,predicted):
    rmse = math.sqrt(mean_squared_error(test, predicted))
    print("The root mean squared error is {}.".format(rmse))

# %%
dataset = pd.read_csv("hourly_smp_v2.csv")
dataset['datetime'] = dataset['datetime'].str.replace('24:00', '0:00')

dataset.index = pd.to_datetime(dataset.datetime)
dataset.drop('datetime', axis=1, inplace=True)

dataset.head()
# Out:
#                         smp
# datetime
# 2018-02-01 01:00:00  116.84
# 2018-02-01 02:00:00  116.84
# 2018-02-01 03:00:00  116.84
# 2018-02-01 04:00:00  116.84
# 2018-02-01 05:00:00  116.84

# %%
dataset = dataset.resample('360t').mean()

# %%
training_set = dataset[:'2020-02']
test_set = dataset['2020-02':]
test_set.head()
# Out:
#                             smp
# datetime
# 2020-02-01 00:00:00  171.505000
# 2020-02-01 06:00:00  119.641667
# 2020-02-01 12:00:00   92.623333
# 2020-02-01 18:00:00  184.990000
# 2020-02-02 00:00:00  102.540000

# %%
# We have chosen '' attribute for prices. Let's see what it looks like
dataset["smp"][:'2020-02'].plot(figsize=(16,4),legend=True)
dataset["smp"]['2020-02':].plot(figsize=(16,4),legend=True)
plt.legend(['Training set (Before 2020)','Test set (2020 and beyond)'])
plt.title('smp')
plt.show()

# %%
sc = MinMaxScaler(feature_range=(0,1))
training_set_scaled = sc.fit_transform(training_set)

# %%
X_train = []
y_train = []
for i in range(28,3036):
    X_train.append(training_set_scaled[i-28:i,0])
    y_train.append(training_set_scaled[i,0])
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
# Reshaping X_train for efficient modelling
X_train = np.reshape(X_train, (X_train.shape[0],X_train.shape[1],1))

# %%
# The LSTM architecture
regressor = Sequential()
# First LSTM layer with Dropout regularisation
regressor.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1],1)))
regressor.add(Dropout(0.2))
# Second LSTM layer
regressor.add(LSTM(units=50, return_sequences=True))
regressor.add(Dropout(0.2))
# Third LSTM layer
regressor.add(LSTM(units=50, return_sequences=True))
regressor.add(Dropout(0.2))
# Fourth LSTM layer
regressor.add(LSTM(units=50))
regressor.add(Dropout(0.2))
# The output layer
regressor.add(Dense(units=1))

# Compiling the RNN
regressor.compile(optimizer='rmsprop',loss='mean_squared_error')
# Fitting to the training set
regressor.fit(X_train,y_train,epochs=100,batch_size=40)
# Out:
# Epoch 1/100
# 3008/3008 [==============================] - 4s 1ms/step - loss: 0.0229
# Epoch 2/100
# 3008/3008 [==============================] - 4s 1ms/step - loss: 0.0170
# Epoch 3/100
# 3008/3008 [==============================] - 4s 1ms/step - loss: 0.0148
# Epoch 4/100
# 2680/3008 [=========================>....] - ETA: 0s - loss: 0.0137
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-327-98317ddf1da1> in <module>
#      19 regressor.compile(optimizer='rmsprop',loss='mean_squared_error')
#      20 # Fitting to the training set
# ---> 21 regressor.fit(X_train,y_train,epochs=100,batch_size=40)
#
# ...

# %%
dataset_total = pd.concat((dataset["smp"][:'2020-02'],dataset["smp"]['2020-02':]),axis=0)
inputs = dataset_total[len(dataset_total)-len(test_set) - 28:].values
inputs = inputs.reshape(-1,1)
inputs  = sc.transform(inputs)

# %%
### Preparing X_test and predicting smp
X_test = []
for i in range(28, 461):
    X_test.append(inputs[i-28:i,0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
predicted_smp = regressor.predict(X_test)
predicted_smp = sc.inverse_transform(predicted_smp)

# %%
df = pd.DataFrame(predicted_smp)
df.index = pd.date_range(test_set.index[0], test_set.index[-1], periods=433)
df.head()
# Out:
#                               0
# 2020-02-01 00:00:00  111.247192
# 2020-02-01 05:59:10   94.705162
# 2020-02-01 11:58:20  104.396347
# 2020-02-01 17:57:30  159.411636
# 2020-02-01 23:56:40  115.050621

# %%
test_set.head()
# Out:
#                             smp
# datetime
# 2020-02-01 00:00:00  171.505000
# 2020-02-01 06:00:00  119.641667
# 2020-02-01 12:00:00   92.623333
# 2020-02-01 18:00:00  184.990000
# 2020-02-02 00:00:00  102.540000

# %%
plot_predictions(test_set,df)
plt.figure(figsize=(10, 40))

# %%
df_1 = df.resample('d').mean()

# %%
df_1.head()
# Out:
#                      0
# 2020-02-01  116.962189
# 2020-02-02  103.689972
# 2020-02-03  100.051010
# 2020-02-04  104.859543
# 2020-02-05  105.886299

# %%
target = pd.read_csv("target_v2.csv")
target.index = pd.to_datetime(target.date)
target.drop('date', axis=1, inplace=True)

# %%
df_2 = target['2020-02':]

# %%
df_1.tail()
# Out:
#                      0
# 2020-05-14  112.256180
# 2020-05-15   89.525803
# 2020-05-16  110.407600
# 2020-05-17   97.436287
# 2020-05-18  119.885124

# %%
df_2.tail()
# Out:
#             smp_max  smp_min  smp_mean  supply
# date
# 2020-05-14   193.28    66.78    100.46   62.70
# 2020-05-15   198.23    61.81    102.38   64.91
# 2020-05-16   220.91    88.50    121.19   61.75
# 2020-05-17   207.75    65.78    116.82   61.55
# 2020-05-18   113.31    66.86     98.98   63.91

# %%
((df_1[0] - df_2['smp_mean']) ** 2).mean() ** .5
# Out:
# 17.97275965918222

# %%
plt.plot(df_1)
plt.plot(df_2['smp_mean'])
