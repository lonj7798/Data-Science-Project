# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
train = pd.read_csv("../Data/Biometric Data Analysis/train.csv")
test = pd.read_csv("../Data/Biometric Data Analysis/test.csv")

# %%
import missingno as msno

msno.matrix(train)

# %%
msno.matrix(test)

# %%
test.filter(regex='_src$',axis=1).head().T.plot()

# %%
test.filter(regex='_dst$',axis=1).head().T.plot()

# %%
train.filter(regex='_dst$',axis=1).head().T.plot()

# %%
train_dst = train_dst.interpolate(methods='linear', axis=1)
test_dst = test_dst.interpolate(methods='linear', axis=1)
# 스팩트럼 데이터에서 보간이 되지 않은 값은 0으로 일괄 처리한다.
train_dst.fillna(0, inplace=True) 
test_dst.fillna(0, inplace=True)
test_dst.head(1)
# Out:
#    650_dst  660_dst       670_dst       680_dst       690_dst       700_dst  \
# 0      0.0      0.0  7.028318e-15  1.199001e-14  1.695171e-14  2.191340e-14
#
#         710_dst       720_dst       730_dst       740_dst  ...       900_dst  \
# 0  2.204989e-14  1.513555e-14  8.221207e-15  1.306867e-15  ...  1.808883e-14
#
#         910_dst       920_dst       930_dst       940_dst       950_dst  \
# 0  1.620565e-14  1.432248e-14  1.165902e-14  8.995570e-15  6.332117e-15
#
#         960_dst       970_dst       980_dst       990_dst
# 0  1.429966e-14  3.393389e-14  5.356813e-14  7.320236e-14
#
# [1 rows x 35 columns]

# %%
test_dst.head().T.plot()

# %%
train_dst.filter(regex='_dst$',axis=1).tail(10).T.plot()
