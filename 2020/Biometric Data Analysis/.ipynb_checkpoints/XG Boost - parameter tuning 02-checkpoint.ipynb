# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv("../Data/Biometric Data Analysis/train.csv").fillna(0)

# %%
data.rho.unique()
data.drop("id", axis=1, inplace=True)

# %%
# group by rho

data_rho_25 = data[data['rho'] == 25]
data_rho_20 = data[data['rho'] == 20]
data_rho_15 = data[data['rho'] == 15]
data_rho_10 = data[data['rho'] == 10]

# %% [markdown]
# ## XG Boost

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
def XY(df):
    X = df.iloc[:,:-4]    
    
    y_hhb = df.iloc[:,-4]
    y_hbo2 = df.iloc[:,-3]
    y_ca = df.iloc[:,-2]
    y_na = df.iloc[:,-1]
    
    return X, y_hhb, y_hbo2, y_ca, y_na

# %% [markdown]
# ### XG Boost Tunning with Hyperopt
#
# https://medium.com/analytics-vidhya/hyperparameter-tuning-hyperopt-bayesian-optimization-for-xgboost-and-neural-network-8aedf278a1c9

# %%
import hyperopt
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials

# %%
def objective(space):
    print(space)
    clf = xgb.XGBRegressor(objective ='reg:squarederror', n_estimators =2200,colsample_bytree=space['colsample_bytree'],
                           learning_rate = .3,
                            max_depth = int(space['max_depth']),
                            min_child_weight = space['min_child_weight'],
                            subsample = space['subsample'],
                           gamma = space['gamma'],
                           reg_lambda = space['reg_lambda'],
                           reg_alpha = space['reg_alpha'])

    eval_set  = [(X_train, y_train), (X_test, y_test)]

    clf.fit(X_train, y_train,
            eval_set=eval_set, eval_metric="rmse",
            early_stopping_rounds=10,verbose=False)

    pred = clf.predict(X_test)
    mse_scr = mean_squared_error(y_test, pred)
    print ("SCORE:", np.sqrt(mse_scr))
    #change the metric if you like
    return {'loss':mse_scr, 'status': STATUS_OK }

space ={'max_depth': hp.quniform("x_max_depth", 4, 15, 1),
        'min_child_weight': hp.quniform ('x_min_child', 1, 10, 1),
        'subsample': hp.uniform ('x_subsample', 0.7, 1),
        'gamma' : hp.uniform ('x_gamma', 0.1,0.5),
        'colsample_bytree' : hp.uniform ('x_colsample_bytree', 0.7,1),
        'reg_lambda' : hp.uniform ('x_reg_lambda', 0,1),
        'reg_alpha' : hp.uniform ('x_reg_alpha', 0,1)
    }

# %%
X, y_hhb, y_hbo2, y_ca, y_na = XY(data_rho_25)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_hhb, test_size=0.25, shuffle=1234)

trials = Trials()
best_hhb = fmin(fn=objective,
            space=space,
            algo=tpe.suggest,
            max_evals=100,
            trials=trials)

X_train, X_test, y_train, y_test = train_test_split(X, y_hbo2, test_size=0.25, shuffle=1234)

trials = Trials()
best_hbo2 = fmin(fn=objective,
            space=space,
            algo=tpe.suggest,
            max_evals=100,
            trials=trials)

X_train, X_test, y_train, y_test = train_test_split(X, y_ca, test_size=0.25, shuffle=1234)

trials = Trials()
best_ca = fmin(fn=objective,
            space=space,
            algo=tpe.suggest,
            max_evals=100,
            trials=trials)

X_train, X_test, y_train, y_test = train_test_split(X, y_na, test_size=0.25, shuffle=1234)

trials = Trials()
best_na = fmin(fn=objective,
            space=space,
            algo=tpe.suggest,
            max_evals=100,
            trials=trials)
# Out:
# {'colsample_bytree': 0.9553204200083195, 'gamma': 0.36897476068043245, 'max_depth': 6.0, 'min_child_weight': 8.0, 'reg_alpha': 0.6944384482658559, 'reg_lambda': 0.1334920176276707, 'subsample': 0.9570077640723701}
# SCORE:
# 1.4200321999680545
# {'colsample_bytree': 0.7419918251794856, 'gamma': 0.18666128658433923, 'max_depth': 12.0, 'min_child_weight': 7.0, 'reg_alpha': 0.28368333207319774, 'reg_lambda': 0.3049170572066505, 'subsample': 0.9802391748182668}
# SCORE:
# 1.4199335848230343
# {'colsample_bytree': 0.9862188854612, 'gamma': 0.4115564944082356, 'max_depth': 13.0, 'min_child_weight': 2.0, 'reg_alpha': 0.9517630926388806, 'reg_lambda': 0.215309365217207, 'subsample': 0.8094881158220399}
# SCORE:
# 1.55388353422823
# {'colsample_bytree': 0.834737414099493, 'gamma': 0.47520653902472143, 'max_depth': 5.0, 'min_child_weight': 3.0, 'reg_alpha': 0.46000036176549375, 'reg_lambda': 0.10773315684541895, 'subsample': 0.849786963084256}
# SCORE:
# 1.4209300688820738
# {'colsample_bytree': 0.789807898504888, 'gamma': 0.12085313550079141, 'max_depth': 5.0, 'min_child_weight': 5.0, 'reg_alpha': 0.2075224836121764, 'reg_lambda': 0.7277231567367531, 'subsample': 0.9858432687176041}
# SCORE:
# 1.3895995427451027
# {'colsample_bytree': 0.955414778209407, 'gamma': 0.27470020438733844, 'max_depth': 11.0, 'min_child_weight': 8.0, 'reg_alpha': 0.23831903221837447, 'reg_lambda': 0.7892172596123528, 'subsample': 0.9711570806461485}
# SCORE:
# 1.4597464160583704
# {'colsample_bytree': 0.8904522381163951, 'gamma': 0.12084114088667396, 'max_depth': 6.0, 'min_child_weight': 3.0, 'reg_alpha': 0.5425421092819337, 'reg_lambda': 0.23012470266649476, 'subsample': 0.8545069054398841}
# SCORE:
# 1.5030678039268701
# {'colsample_bytree': 0.9817418204621066, 'gamma': 0.250185560294541, 'max_depth': 4.0, 'min_child_weight': 1.0, 'reg_alpha': 0.6920898478418549, 'reg_lambda': 0.030826328691919147, 'subsample': 0.9069358433081202}
# SCORE:
# 1.446799979665094
# {'colsample_bytree': 0.8973732364108804, 'gamma': 0.26104994452293306, 'max_depth': 6.0, 'min_child_weight': 8.0, 'reg_alpha': 0.24435528755666902, 'reg_lambda': 0.8390998186044067, 'subsample': 0.7564675124334677}
# SCORE:
# 1.4405406515726344
# {'colsample_bytree': 0.9350343510324169, 'gamma': 0.339278716151247, 'max_depth': 11.0, 'min_child_weight': 4.0, 'reg_alpha': 0.04294955338960271, 'reg_lambda': 0.2754907470319651, 'subsample': 0.9517051514504877}
# SCORE:
# 1.5049649628900976
# {'colsample_bytree': 0.8471377695134156, 'gamma': 0.21819705464025685, 'max_depth': 11.0, 'min_child_weight': 9.0, 'reg_alpha': 0.2541271028109392, 'reg_lambda': 0.5214621166833268, 'subsample': 0.7263717458040695}
# SCORE:
# 1.4639837558075548
# {'colsample_bytree': 0.7419593276412156, 'gamma': 0.2735938924394777, 'max_depth': 9.0, 'min_child_weight': 3.0, 'reg_alpha': 0.42118843154920826, 'reg_lambda': 0.36002974579501357, 'subsample': 0.9775753231726825}
# SCORE:
# 1.4523918203206716
# {'colsample_bytree': 0.9415196155114421, 'gamma': 0.24831463493040534, 'max_depth': 6.0, 'min_child_weight': 2.0, 'reg_alpha': 0.77165801845376, 'reg_lambda': 0.5183414696446981, 'subsample': 0.7543451816553322}
# SCORE:
# 1.426382380271615
# {'colsample_bytree': 0.9304511504358255, 'gamma': 0.22853239707628484, 'max_depth': 7.0, 'min_child_weight': 6.0, 'reg_alpha': 0.652054681603435, 'reg_lambda': 0.39108664734150955, 'subsample': 0.8295047069146024}
# SCORE:
# 1.4486317341725385
# {'colsample_bytree': 0.8379995801202225, 'gamma': 0.12134338739450215, 'max_depth': 8.0, 'min_child_weight': 9.0, 'reg_alpha': 0.20611237796934812, 'reg_lambda': 0.6433543734412915, 'subsample': 0.8540741852332234}
# SCORE:
# 1.4584371945551344
# {'colsample_bytree': 0.7125854396496437, 'gamma': 0.3529041774341509, 'max_depth': 13.0, 'min_child_weight': 7.0, 'reg_alpha': 0.5951096128658101, 'reg_lambda': 0.08680756689794855, 'subsample': 0.9022190452256752}
# SCORE:
# 1.4024770178942016
# {'colsample_bytree': 0.871880926210891, 'gamma': 0.3144089926202843, 'max_depth': 7.0, 'min_child_weight': 2.0, 'reg_alpha': 0.944218790738001, 'reg_lambda': 0.2624909699815968, 'subsample': 0.7530816463511378}
# SCORE:
# 1.40260732470824
# {'colsample_bytree': 0.9174971865707999, 'gamma': 0.1672726390105161, 'max_depth': 13.0, 'min_child_weight': 9.0, 'reg_alpha': 0.6537027847443916, 'reg_lambda': 0.8914250623498059, 'subsample': 0.7030909509692594}
# SCORE:
# 1.4528946182111344
# {'colsample_bytree': 0.9403171227940106, 'gamma': 0.3100740768281627, 'max_depth': 8.0, 'min_child_weight': 3.0, 'reg_alpha': 0.2492905550297504, 'reg_lambda': 0.5572475373202297, 'subsample': 0.9403381155666002}
# SCORE:
# 1.431199053759652
# {'colsample_bytree': 0.7756545082881172, 'gamma': 0.24710684477009642, 'max_depth': 15.0, 'min_child_weight': 1.0, 'reg_alpha': 0.10187113195339226, 'reg_lambda': 0.3348904965620514, 'subsample': 0.7730207971186547}
# SCORE:
# 1.4721896025618706
# {'colsample_bytree': 0.7022726504764706, 'gamma': 0.4316222755027675, 'max_depth': 15.0, 'min_child_weight': 5.0, 'reg_alpha': 0.8468755619671859, 'reg_lambda': 0.6966785647735444, 'subsample': 0.8876271473194286}
# SCORE:
# 1.380119726705281
# {'colsample_bytree': 0.8028700738642757, 'gamma': 0.4932663972379332, 'max_depth': 15.0, 'min_child_weight': 5.0, 'reg_alpha': 0.41204340053567245, 'reg_lambda': 0.7176026930008048, 'subsample': 0.9111253980638522}
# SCORE:
# 1.394859303461069
# {'colsample_bytree': 0.7031373252328484, 'gamma': 0.44218580678787445, 'max_depth': 10.0, 'min_child_weight': 5.0, 'reg_alpha': 0.8348524841250233, 'reg_lambda': 0.6557986648998599, 'subsample': 0.9980984086519354}
# SCORE:
# 1.4596884262536702
# {'colsample_bytree': 0.7845897122364648, 'gamma': 0.4045342231908421, 'max_depth': 4.0, 'min_child_weight': 6.0, 'reg_alpha': 0.8477239741610507, 'reg_lambda': 0.971467739224462, 'subsample': 0.8897852115925424}
# SCORE:
# 1.4707935499189113
# {'colsample_bytree': 0.7503085488392587, 'gamma': 0.44775342947950136, 'max_depth': 14.0, 'min_child_weight': 4.0, 'reg_alpha': 0.33493304086714776, 'reg_lambda': 0.9725119250526844, 'subsample': 0.9317941849510578}
# SCORE:
# 1.4314393402200678
# {'colsample_bytree': 0.8118913586291182, 'gamma': 0.15406587022748877, 'max_depth': 9.0, 'min_child_weight': 4.0, 'reg_alpha': 0.15032417639432116, 'reg_lambda': 0.4302296959690325, 'subsample': 0.878612399049014}
# SCORE:
# 1.429397543471616
# {'colsample_bytree': 0.7009144460012012, 'gamma': 0.393510905846825, 'max_depth': 5.0, 'min_child_weight': 5.0, 'reg_alpha': 0.357023241991008, 'reg_lambda': 0.7406745595766847, 'subsample': 0.8019704755863135}
# SCORE:
# 1.3624160160547478
# {'colsample_bytree': 0.7219833068213571, 'gamma': 0.39200980316245426, 'max_depth': 10.0, 'min_child_weight': 6.0, 'reg_alpha': 0.3664232845727969, 'reg_lambda': 0.5941658946065685, 'subsample': 0.8027237463859427}
# SCORE:
# 1.4865637144942943
# {'colsample_bytree': 0.70011953750666, 'gamma': 0.45088495429606584, 'max_depth': 14.0, 'min_child_weight': 7.0, 'reg_alpha': 0.5297100961594658, 'reg_lambda': 0.8977249674453079, 'subsample': 0.8112675365986659}
# SCORE:
# 1.3723034567552883
# {'colsample_bytree': 0.7278940162661103, 'gamma': 0.3704448044068814, 'max_depth': 14.0, 'min_child_weight': 10.0, 'reg_alpha': 0.5092641740905449, 'reg_lambda': 0.9069970286638287, 'subsample': 0.796734811057116}
# SCORE:
# 1.432169750875558
# {'colsample_bytree': 0.759002629322235, 'gamma': 0.49457675168466614, 'max_depth': 12.0, 'min_child_weight': 7.0, 'reg_alpha': 0.5421833912050464, 'reg_lambda': 0.7888009862980584, 'subsample': 0.786567238081681}
# SCORE:
# 1.5316799619888826
# {'colsample_bytree': 0.7669231655682136, 'gamma': 0.46853720922198594, 'max_depth': 12.0, 'min_child_weight': 7.0, 'reg_alpha': 0.3172963341484057, 'reg_lambda': 0.9910392923306721, 'subsample': 0.8223912488758836}
# SCORE:
# 1.4541018356257651
# {'colsample_bytree': 0.729979939695489, 'gamma': 0.380598976723452, 'max_depth': 5.0, 'min_child_weight': 10.0, 'reg_alpha': 0.001342361343583065, 'reg_lambda': 0.8957039478256378, 'subsample': 0.7295955537799315}
# SCORE:
# 1.4249052539649592
# {'colsample_bytree': 0.8190803713828231, 'gamma': 0.4202752772269943, 'max_depth': 14.0, 'min_child_weight': 7.0, 'reg_alpha': 0.4621397858204493, 'reg_lambda': 0.788296846979262, 'subsample': 0.8359819867729037}
# SCORE:
# 1.4488508636555184
# {'colsample_bytree': 0.7378805266192504, 'gamma': 0.4635520643313305, 'max_depth': 8.0, 'min_child_weight': 8.0, 'reg_alpha': 0.596569197867547, 'reg_lambda': 0.45698405114281465, 'subsample': 0.868861667444853}
# SCORE:
# 1.42009568632473
# {'colsample_bytree': 0.8691755790853113, 'gamma': 0.33922522087640794, 'max_depth': 5.0, 'min_child_weight': 6.0, 'reg_alpha': 0.7369964565603416, 'reg_lambda': 0.8430187714384128, 'subsample': 0.8155624983439278}
# SCORE:
# 1.430200297174423
# {'colsample_bytree': 0.7105180321764235, 'gamma': 0.49883247523532503, 'max_depth': 7.0, 'min_child_weight': 4.0, 'reg_alpha': 0.378017150241842, 'reg_lambda': 0.9361449244309552, 'subsample': 0.7933827758916209}
# SCORE:
# 1.45176592304656
# {'colsample_bytree': 0.7967510228752761, 'gamma': 0.4054353441684337, 'max_depth': 10.0, 'min_child_weight': 8.0, 'reg_alpha': 0.13733329806425518, 'reg_lambda': 0.833273372575996, 'subsample': 0.7790245676681401}
# SCORE:
# 1.4246636903472112
# {'colsample_bytree': 0.7004804648902102, 'gamma': 0.35255567698073337, 'max_depth': 13.0, 'min_child_weight': 5.0, 'reg_alpha': 0.4631718573301221, 'reg_lambda': 0.7519072827060236, 'subsample': 0.7090484076428741}
# SCORE:
# 1.482265852854944
# {'colsample_bytree': 0.8255025291990346, 'gamma': 0.2947796895064799, 'max_depth': 4.0, 'min_child_weight': 8.0, 'reg_alpha': 0.9984183090877964, 'reg_lambda': 0.6188935681760683, 'subsample': 0.7691800301392185}
# SCORE:
# 1.4337632080211187
# {'colsample_bytree': 0.7598961834614255, 'gamma': 0.4518042698367751, 'max_depth': 11.0, 'min_child_weight': 6.0, 'reg_alpha': 0.580022890144995, 'reg_lambda': 0.6804057458559567, 'subsample': 0.8447404225946841}
# SCORE:
# 1.4508029136971885
# {'colsample_bytree': 0.863243832927193, 'gamma': 0.3897864209385567, 'max_depth': 5.0, 'min_child_weight': 9.0, 'reg_alpha': 0.2965511327367525, 'reg_lambda': 0.7567356531701956, 'subsample': 0.742195270440897}
# SCORE:
# 1.3922564875045358
# {'colsample_bytree': 0.7770721331230163, 'gamma': 0.48256054979576885, 'max_depth': 9.0, 'min_child_weight': 7.0, 'reg_alpha': 0.5216850643133335, 'reg_lambda': 0.5715911397613993, 'subsample': 0.8124867996447863}
# SCORE:
# 1.4393508728937423
# {'colsample_bytree': 0.9796955513590602, 'gamma': 0.423869509758766, 'max_depth': 6.0, 'min_child_weight': 2.0, 'reg_alpha': 0.062215451719892845, 'reg_lambda': 0.8548763602556843, 'subsample': 0.8686990220057161}
# SCORE:
# 1.4537598812625465
# {'colsample_bytree': 0.9965490567839028, 'gamma': 0.2881362204102693, 'max_depth': 12.0, 'min_child_weight': 4.0, 'reg_alpha': 0.17863846673244055, 'reg_lambda': 0.1509325467043296, 'subsample': 0.7195809623695891}
# SCORE:
# 1.529453514846676
# {'colsample_bytree': 0.7171881653189519, 'gamma': 0.32971950948552525, 'max_depth': 7.0, 'min_child_weight': 3.0, 'reg_alpha': 0.6717323963560354, 'reg_lambda': 0.477766593694024, 'subsample': 0.7404825877521481}
# SCORE:
# 1.3863670397620378
# {'colsample_bytree': 0.753687515620548, 'gamma': 0.35756019107339587, 'max_depth': 11.0, 'min_child_weight': 6.0, 'reg_alpha': 0.7410612350278826, 'reg_lambda': 0.5325488468823493, 'subsample': 0.8383037378063687}
# SCORE:
# 1.4237090123549159
# {'colsample_bytree': 0.9034067476928066, 'gamma': 0.31865655767969336, 'max_depth': 8.0, 'min_child_weight': 7.0, 'reg_alpha': 0.4098575994831334, 'reg_lambda': 0.9428113558372287, 'subsample': 0.8235760966784811}
# SCORE:
# 1.4606982667011847
# {'colsample_bytree': 0.740038284984432, 'gamma': 0.21236822783897447, 'max_depth': 14.0, 'min_child_weight': 5.0, 'reg_alpha': 0.6054913100002932, 'reg_lambda': 0.8194927377623789, 'subsample': 0.8592349803429625}
# SCORE:
# 1.4728900055572294
# {'colsample_bytree': 0.9630315117377503, 'gamma': 0.47730196299408645, 'max_depth': 13.0, 'min_child_weight': 10.0, 'reg_alpha': 0.4803515455151481, 'reg_lambda': 0.014373104803841352, 'subsample': 0.9162402029014399}
# SCORE:
# 1.4887552847063255
# {'colsample_bytree': 0.8556296811000985, 'gamma': 0.43443594603429847, 'max_depth': 6.0, 'min_child_weight': 8.0, 'reg_alpha': 0.26698732429468963, 'reg_lambda': 0.7328629790647689, 'subsample': 0.7822792045191894}
# SCORE:
# 1.43440548863067
# {'colsample_bytree': 0.884203757331644, 'gamma': 0.45969007853065375, 'max_depth': 9.0, 'min_child_weight': 9.0, 'reg_alpha': 0.3698406255563177, 'reg_lambda': 0.6168846148816752, 'subsample': 0.7576804237531383}
# SCORE:
# 1.4517320931825857
# {'colsample_bytree': 0.8464917057528205, 'gamma': 0.36702198213567727, 'max_depth': 12.0, 'min_child_weight': 3.0, 'reg_alpha': 0.8991816030235956, 'reg_lambda': 0.6719918952339237, 'subsample': 0.7669518923622503}
# SCORE:
# 1.5023959422550437
# {'colsample_bytree': 0.7920243130997023, 'gamma': 0.27551883169704483, 'max_depth': 11.0, 'min_child_weight': 6.0, 'reg_alpha': 0.21175955418518944, 'reg_lambda': 0.8790127777799501, 'subsample': 0.8021114122681231}
# SCORE:
# 1.4890853466045288
# {'colsample_bytree': 0.8323599291116848, 'gamma': 0.40733128555469605, 'max_depth': 5.0, 'min_child_weight': 5.0, 'reg_alpha': 0.7982355264953005, 'reg_lambda': 0.20501671236580982, 'subsample': 0.9599096040764435}
# SCORE:
# 1.3996238858966534
# {'colsample_bytree': 0.8090396382026925, 'gamma': 0.39272498562314206, 'max_depth': 10.0, 'min_child_weight': 1.0, 'reg_alpha': 0.62548424314286, 'reg_lambda': 0.9393431116480964, 'subsample': 0.895870331229859}
# SCORE:
# 1.418320035387506
# {'colsample_bytree': 0.7063392112441271, 'gamma': 0.4177705844015174, 'max_depth': 8.0, 'min_child_weight': 4.0, 'reg_alpha': 0.7117925098597053, 'reg_lambda': 0.39793597099748257, 'subsample': 0.9192588633948411}
# SCORE:
# 1.458199678433419
# {'colsample_bytree': 0.7792024551484028, 'gamma': 0.18996500964679972, 'max_depth': 15.0, 'min_child_weight': 2.0, 'reg_alpha': 0.42469340789179333, 'reg_lambda': 0.9996083618033114, 'subsample': 0.8672389053124779}
# SCORE:
# 1.4685042187399164
# {'colsample_bytree': 0.7465663056367865, 'gamma': 0.33619688309629486, 'max_depth': 7.0, 'min_child_weight': 9.0, 'reg_alpha': 0.29186424409335443, 'reg_lambda': 0.713765954912739, 'subsample': 0.8470555375265822}
# SCORE:
# 1.4397631735465677
# {'colsample_bytree': 0.7306521114636901, 'gamma': 0.1072757629957452, 'max_depth': 4.0, 'min_child_weight': 5.0, 'reg_alpha': 0.5563094544143266, 'reg_lambda': 0.801212485235623, 'subsample': 0.7423902351725469}
# SCORE:
# 1.4617204827535566
# {'colsample_bytree': 0.9171597133468268, 'gamma': 0.4397666303489488, 'max_depth': 6.0, 'min_child_weight': 8.0, 'reg_alpha': 0.3311732069302226, 'reg_lambda': 0.31455772966594964, 'subsample': 0.8812762221980973}
# SCORE:
# 1.3946033202462922
# {'colsample_bytree': 0.7180699391059002, 'gamma': 0.3098303131996957, 'max_depth': 13.0, 'min_child_weight': 7.0, 'reg_alpha': 0.0989648862537929, 'reg_lambda': 0.6290425201540586, 'subsample': 0.7004427650087586}
# SCORE:
# 1.465868843083614
# {'colsample_bytree': 0.7671145938990831, 'gamma': 0.48408221102364296, 'max_depth': 8.0, 'min_child_weight': 6.0, 'reg_alpha': 0.4872955293658694, 'reg_lambda': 0.8682976912181878, 'subsample': 0.8266722880192204}
# SCORE:
# 1.441506994885639
# {'colsample_bytree': 0.8004301916401049, 'gamma': 0.37310086876163423, 'max_depth': 9.0, 'min_child_weight': 3.0, 'reg_alpha': 0.5640745038180089, 'reg_lambda': 0.4952949266350955, 'subsample': 0.7904264452968066}
# SCORE:
# 1.4206748211836162
# {'colsample_bytree': 0.7686095981656887, 'gamma': 0.3580709330638493, 'max_depth': 14.0, 'min_child_weight': 4.0, 'reg_alpha': 0.6317355701878656, 'reg_lambda': 0.7517002567338021, 'subsample': 0.76249020936165}
# SCORE:
# 1.429616659129684
# {'colsample_bytree': 0.7018342625379228, 'gamma': 0.42480952660856497, 'max_depth': 15.0, 'min_child_weight': 4.0, 'reg_alpha': 0.9141823405354281, 'reg_lambda': 0.5686239186941582, 'subsample': 0.9320351790915382}
# SCORE:
# 1.5147428305422144
# {'colsample_bytree': 0.7269839314934693, 'gamma': 0.45787555575808075, 'max_depth': 15.0, 'min_child_weight': 5.0, 'reg_alpha': 0.9775164720105549, 'reg_lambda': 0.6728930608782084, 'subsample': 0.9865629776626492}
# SCORE:
# 1.508212271094528
# {'colsample_bytree': 0.7356421714825331, 'gamma': 0.43254751673269665, 'max_depth': 14.0, 'min_child_weight': 5.0, 'reg_alpha': 0.8762869417122062, 'reg_lambda': 0.7146375289003875, 'subsample': 0.8881670426040204}
# SCORE:
# 1.3834138821062754
# {'colsample_bytree': 0.712879690437011, 'gamma': 0.3966871454658897, 'max_depth': 15.0, 'min_child_weight': 6.0, 'reg_alpha': 0.8210055809996861, 'reg_lambda': 0.7789415343905186, 'subsample': 0.8590308254058544}
# SCORE:
# 1.4399158267425671
# {'colsample_bytree': 0.7007183366676955, 'gamma': 0.3788453626825395, 'max_depth': 13.0, 'min_child_weight': 7.0, 'reg_alpha': 0.4331842783358363, 'reg_lambda': 0.6977895280458926, 'subsample': 0.9048390379460981}
# SCORE:
# 1.3948845387564006
# {'colsample_bytree': 0.7472355221494412, 'gamma': 0.49289654877638406, 'max_depth': 14.0, 'min_child_weight': 6.0, 'reg_alpha': 0.7697726122208443, 'reg_lambda': 0.9102060838840456, 'subsample': 0.8054265872456565}
# SCORE:
# 1.4640783426520152
# {'colsample_bytree': 0.7208008052688216, 'gamma': 0.46876411511594085, 'max_depth': 12.0, 'min_child_weight': 5.0, 'reg_alpha': 0.5225275646736467, 'reg_lambda': 0.6004759493007252, 'subsample': 0.8375564909781916}
# SCORE:
# 1.47928534843843
# {'colsample_bytree': 0.7579382577340219, 'gamma': 0.448684996447391, 'max_depth': 15.0, 'min_child_weight': 7.0, 'reg_alpha': 0.001781761539497162, 'reg_lambda': 0.5433731894423455, 'subsample': 0.8188251905788859}
# SCORE:
# 1.3976466961354055
# {'colsample_bytree': 0.7833803346954437, 'gamma': 0.41418184061448904, 'max_depth': 14.0, 'min_child_weight': 4.0, 'reg_alpha': 0.2296422252525351, 'reg_lambda': 0.8096715645177412, 'subsample': 0.8782481635984298}
# SCORE:
# 1.4605860820043048
# {'colsample_bytree': 0.7110406669615965, 'gamma': 0.3241463270076629, 'max_depth': 11.0, 'min_child_weight': 6.0, 'reg_alpha': 0.683996009983719, 'reg_lambda': 0.9587967878879688, 'subsample': 0.9513830709492223}
# SCORE:
# 1.4052012177394393
# {'colsample_bytree': 0.7000089704002923, 'gamma': 0.34835363962019555, 'max_depth': 12.0, 'min_child_weight': 8.0, 'reg_alpha': 0.39542049978272303, 'reg_lambda': 0.6559783818283771, 'subsample': 0.7786853757339068}
# SCORE:
# 1.4014868156946374
# {'colsample_bytree': 0.7352993363347965, 'gamma': 0.498217570236749, 'max_depth': 13.0, 'min_child_weight': 3.0, 'reg_alpha': 0.946456036377341, 'reg_lambda': 0.43844585252654594, 'subsample': 0.8339858320187142}
# SCORE:
# 1.4605518350543227
# {'colsample_bytree': 0.7258292940489364, 'gamma': 0.384865136887691, 'max_depth': 10.0, 'min_child_weight': 5.0, 'reg_alpha': 0.44914984304668737, 'reg_lambda': 0.9063570987650452, 'subsample': 0.7988509927331328}
# SCORE:
# 1.4168170183187452
# {'colsample_bytree': 0.7902733080196483, 'gamma': 0.40057782187864566, 'max_depth': 15.0, 'min_child_weight': 7.0, 'reg_alpha': 0.1527745389845452, 'reg_lambda': 0.7708621029743578, 'subsample': 0.8106313100614834}
# SCORE:
# 1.4084920229805404
# {'colsample_bytree': 0.8149616647106824, 'gamma': 0.43067797165408594, 'max_depth': 4.0, 'min_child_weight': 4.0, 'reg_alpha': 0.3584771824110442, 'reg_lambda': 0.8451388345721706, 'subsample': 0.7483600596637545}
# SCORE:
# 1.4060065011261471
# {'colsample_bytree': 0.9509198909268406, 'gamma': 0.47146335737253997, 'max_depth': 5.0, 'min_child_weight': 2.0, 'reg_alpha': 0.17822422186735842, 'reg_lambda': 0.38838669782301294, 'subsample': 0.7303046016405813}
# SCORE:
# 1.417108542331404
# {'colsample_bytree': 0.7426113279188788, 'gamma': 0.2382145548658334, 'max_depth': 14.0, 'min_child_weight': 6.0, 'reg_alpha': 0.6442847721723736, 'reg_lambda': 0.5136847517651815, 'subsample': 0.8523011038203245}
# SCORE:
# 1.4459203421952576
# {'colsample_bytree': 0.7720786643579673, 'gamma': 0.30178926004105655, 'max_depth': 12.0, 'min_child_weight': 9.0, 'reg_alpha': 0.7128483778324511, 'reg_lambda': 0.5960789502457162, 'subsample': 0.9244785271812498}
# SCORE:
# 1.4151059740681171
# {'colsample_bytree': 0.7610124082432981, 'gamma': 0.25674663078143667, 'max_depth': 13.0, 'min_child_weight': 8.0, 'reg_alpha': 0.8503879064827029, 'reg_lambda': 0.9772230338039957, 'subsample': 0.8980618971828158}
# SCORE:
# 1.446991999248029
# {'colsample_bytree': 0.7069104678756511, 'gamma': 0.44153784906147747, 'max_depth': 9.0, 'min_child_weight': 3.0, 'reg_alpha': 0.2712545676478861, 'reg_lambda': 0.6883715361728067, 'subsample': 0.8438022382806024}
# SCORE:
# 1.4145203555474806
# {'colsample_bytree': 0.8812202800059684, 'gamma': 0.4544762753290064, 'max_depth': 7.0, 'min_child_weight': 6.0, 'reg_alpha': 0.037307500458324705, 'reg_lambda': 0.730132707589834, 'subsample': 0.7181496641364302}
# SCORE:
# 1.4174498730235392
# {'colsample_bytree': 0.749870913853077, 'gamma': 0.48603914934583803, 'max_depth': 10.0, 'min_child_weight': 5.0, 'reg_alpha': 0.7641910989937755, 'reg_lambda': 0.8216180130405105, 'subsample': 0.8735007270470165}
# SCORE:
# 1.456585332302087
# {'colsample_bytree': 0.7150791879996152, 'gamma': 0.34315961455504734, 'max_depth': 11.0, 'min_child_weight': 4.0, 'reg_alpha': 0.31556062763934817, 'reg_lambda': 0.6479708453181402, 'subsample': 0.8632421235745086}
# SCORE:
# 1.4443513358939761
# {'colsample_bytree': 0.7324546869897056, 'gamma': 0.36293068435338705, 'max_depth': 15.0, 'min_child_weight': 7.0, 'reg_alpha': 0.7936843287975991, 'reg_lambda': 0.8614928232888609, 'subsample': 0.7731379819718391}
# SCORE:
# 1.5020606945862973
# {'colsample_bytree': 0.8359337848840543, 'gamma': 0.279407510586201, 'max_depth': 14.0, 'min_child_weight': 5.0, 'reg_alpha': 0.9832402142444151, 'reg_lambda': 0.4707267356717662, 'subsample': 0.8894826945673073}
# SCORE:
# 1.4362077498451231
# {'colsample_bytree': 0.9003675348008748, 'gamma': 0.4148245751691648, 'max_depth': 8.0, 'min_child_weight': 7.0, 'reg_alpha': 0.343812888427382, 'reg_lambda': 0.9977890121317716, 'subsample': 0.9431281586917596}
# SCORE:
# 1.4673282746709642
# {'colsample_bytree': 0.9203581863710592, 'gamma': 0.13988486559703897, 'max_depth': 6.0, 'min_child_weight': 8.0, 'reg_alpha': 0.39088014859868697, 'reg_lambda': 0.9222277575150826, 'subsample': 0.9110392561311306}
# SCORE:
# 1.42229558376141
# {'colsample_bytree': 0.8278244309435391, 'gamma': 0.38441755544103956, 'max_depth': 5.0, 'min_child_weight': 5.0, 'reg_alpha': 0.5019314184222745, 'reg_lambda': 0.7611407463360027, 'subsample': 0.8318759698175666}
# SCORE:
# 1.3698447989507727
# {'colsample_bytree': 0.9691406965691669, 'gamma': 0.37776741327629276, 'max_depth': 5.0, 'min_child_weight': 1.0, 'reg_alpha': 0.5334108688742957, 'reg_lambda': 0.8905465199336612, 'subsample': 0.8298600111760593}
# SCORE:
# 1.4296253885422352
# {'colsample_bytree': 0.8523182888523105, 'gamma': 0.3277787703497639, 'max_depth': 4.0, 'min_child_weight': 6.0, 'reg_alpha': 0.6146410261901607, 'reg_lambda': 0.7519014843232352, 'subsample': 0.817429341606769}
# SCORE:
# 1.4670041267607838
# {'colsample_bytree': 0.8221526944082626, 'gamma': 0.3056745832609349, 'max_depth': 6.0, 'min_child_weight': 4.0, 'reg_alpha': 0.5015620138298279, 'reg_lambda': 0.8279566383004489, 'subsample': 0.8061035994824614}
# SCORE:
# 1.4375739095533366
# {'colsample_bytree': 0.8286553489311281, 'gamma': 0.40430790738481015, 'max_depth': 7.0, 'min_child_weight': 3.0, 'reg_alpha': 0.5690638346523496, 'reg_lambda': 0.9502177479542555, 'subsample': 0.7836782523202149}
# SCORE:
# 1.4599097225208362
# {'colsample_bytree': 0.8066118949087113, 'gamma': 0.26693990634514414, 'max_depth': 5.0, 'min_child_weight': 7.0, 'reg_alpha': 0.6667502018273322, 'reg_lambda': 0.09648725622703186, 'subsample': 0.7489076209831248}
# SCORE:
# 1.3785063166109446
# {'colsample_bytree': 0.9883862547836019, 'gamma': 0.38746572756440545, 'max_depth': 4.0, 'min_child_weight': 5.0, 'reg_alpha': 0.5835097844372291, 'reg_lambda': 0.8010816771748599, 'subsample': 0.7901369181505522}
# SCORE:
# 1.4242283613527
# {'colsample_bytree': 0.8642923003361471, 'gamma': 0.33647217591518325, 'max_depth': 6.0, 'min_child_weight': 10.0, 'reg_alpha': 0.4717867882108826, 'reg_lambda': 0.06453567525106368, 'subsample': 0.7610669198853534}
# SCORE:
# 1.4312273552883747
# 100%|██████████████████████████████████████████████| 100/100 [01:16<00:00,  1.31trial/s, best loss: 1.8561774008024912]
# {'colsample_bytree': 0.9586543079505043, 'gamma': 0.3818086432461891, 'max_depth': 10.0, 'min_child_weight': 8.0, 'reg_alpha': 0.6479127589446598, 'reg_lambda': 0.0400838826176485, 'subsample': 0.8677594550489429}
# SCORE:
# 0.8375356700196833
# {'colsample_bytree': 0.9828120050232501, 'gamma': 0.32617303887134685, 'max_depth': 5.0, 'min_child_weight': 2.0, 'reg_alpha': 0.7916388392326719, 'reg_lambda': 0.45964083823840207, 'subsample': 0.8548797082605454}
# SCORE:
# 0.8272211885131358
# {'colsample_bytree': 0.8607719637569136, 'gamma': 0.12107152328994064, 'max_depth': 7.0, 'min_child_weight': 6.0, 'reg_alpha': 0.26292830530630684, 'reg_lambda': 0.5976544395942957, 'subsample': 0.8374782214442102}
# SCORE:
# 0.8450583312483221
# {'colsample_bytree': 0.7479409453375685, 'gamma': 0.24895371802662042, 'max_depth': 15.0, 'min_child_weight': 3.0, 'reg_alpha': 0.03370229875729913, 'reg_lambda': 0.019681982816335264, 'subsample': 0.7394477315566655}
# SCORE:
# 0.8704242526289258
# {'colsample_bytree': 0.9189871130737712, 'gamma': 0.24904504785898796, 'max_depth': 5.0, 'min_child_weight': 4.0, 'reg_alpha': 0.7221321638492751, 'reg_lambda': 0.35075556516404427, 'subsample': 0.7898700337723967}
# SCORE:
# 0.8210311604724267
# {'colsample_bytree': 0.7347552161951594, 'gamma': 0.2163694292684414, 'max_depth': 9.0, 'min_child_weight': 3.0, 'reg_alpha': 0.029432761236550475, 'reg_lambda': 0.19270862229130503, 'subsample': 0.9554479046191036}
# SCORE:
# 0.8204395355464247
# {'colsample_bytree': 0.7030172137675942, 'gamma': 0.38237355125204775, 'max_depth': 10.0, 'min_child_weight': 4.0, 'reg_alpha': 0.674178190165255, 'reg_lambda': 0.22724293477152258, 'subsample': 0.8324690175063867}
# ...
# 1.8699926499629786
# {'colsample_bytree': 0.8379087421490723, 'gamma': 0.18344925042035803, 'max_depth': 4.0, 'min_child_weight': 10.0, 'reg_alpha': 0.4776190046417233, 'reg_lambda': 0.31568368183189066, 'subsample': 0.8725546650837228}
# SCORE:
# 1.8340544284285016
# {'colsample_bytree': 0.8046858116298593, 'gamma': 0.1576088558358614, 'max_depth': 4.0, 'min_child_weight': 9.0, 'reg_alpha': 0.42161407791056293, 'reg_lambda': 0.5293565617310694, 'subsample': 0.918709501696529}
# SCORE:
# 1.8042378044635352
# {'colsample_bytree': 0.8024920288145695, 'gamma': 0.15558457194628042, 'max_depth': 6.0, 'min_child_weight': 10.0, 'reg_alpha': 0.40268305398308146, 'reg_lambda': 0.6080009116787803, 'subsample': 0.9184975633758122}
# SCORE:
# 1.829201028302402
# {'colsample_bytree': 0.7224810120515164, 'gamma': 0.12454368994844767, 'max_depth': 4.0, 'min_child_weight': 9.0, 'reg_alpha': 0.33611817617398176, 'reg_lambda': 0.5291280946672385, 'subsample': 0.9292763430041858}
# SCORE:
# 1.7826629185858214
# {'colsample_bytree': 0.7163837917402033, 'gamma': 0.10148063137534961, 'max_depth': 5.0, 'min_child_weight': 9.0, 'reg_alpha': 0.332486347707552, 'reg_lambda': 0.5335649655819001, 'subsample': 0.9284037155524703}
# SCORE:
# 1.8245270913642317
# {'colsample_bytree': 0.7220955986361635, 'gamma': 0.18841117441959268, 'max_depth': 6.0, 'min_child_weight': 9.0, 'reg_alpha': 0.43841463561789407, 'reg_lambda': 0.6677215911653815, 'subsample': 0.9527152551426447}
# SCORE:
# 1.872886036056958
# {'colsample_bytree': 0.7500042491269588, 'gamma': 0.12060484462741475, 'max_depth': 4.0, 'min_child_weight': 8.0, 'reg_alpha': 0.3810490347727297, 'reg_lambda': 0.4883039499803586, 'subsample': 0.8864097766550391}
# SCORE:
# 1.8072628678925053
# {'colsample_bytree': 0.7722446771273954, 'gamma': 0.12880804523892092, 'max_depth': 5.0, 'min_child_weight': 9.0, 'reg_alpha': 0.19325263452796723, 'reg_lambda': 0.7525285352378904, 'subsample': 0.902058450748776}
# SCORE:
# 1.824232281616733
# {'colsample_bytree': 0.7834107373754394, 'gamma': 0.23943306357948002, 'max_depth': 7.0, 'min_child_weight': 7.0, 'reg_alpha': 0.30226833061929814, 'reg_lambda': 0.389615922400665, 'subsample': 0.9807193775705498}
# SCORE:
# 1.8676954486861566
# {'colsample_bytree': 0.8782185362976423, 'gamma': 0.17483800438646036, 'max_depth': 5.0, 'min_child_weight': 4.0, 'reg_alpha': 0.3322364216945381, 'reg_lambda': 0.5942417087679996, 'subsample': 0.8667164263914446}
# SCORE:
# 1.8448830299600665
# {'colsample_bytree': 0.7103027844988047, 'gamma': 0.41161269369157205, 'max_depth': 6.0, 'min_child_weight': 5.0, 'reg_alpha': 0.43211839286243253, 'reg_lambda': 0.5560653644064064, 'subsample': 0.9110773464369887}
# SCORE:
# 1.8535908789557731
# {'colsample_bytree': 0.8144284455170903, 'gamma': 0.26055309313384434, 'max_depth': 4.0, 'min_child_weight': 6.0, 'reg_alpha': 0.12923393494485394, 'reg_lambda': 0.48504515537841586, 'subsample': 0.841722135588763}
# SCORE:
# 1.8179203593635447
# {'colsample_bytree': 0.8475568101923411, 'gamma': 0.21198579082003655, 'max_depth': 5.0, 'min_child_weight': 8.0, 'reg_alpha': 0.5042396784181412, 'reg_lambda': 0.6391978991467224, 'subsample': 0.7906222807828428}
# SCORE:
# 1.8617151123675404
# {'colsample_bytree': 0.7393866481100643, 'gamma': 0.34441050869635803, 'max_depth': 6.0, 'min_child_weight': 7.0, 'reg_alpha': 0.2567607247663216, 'reg_lambda': 0.4515001380007797, 'subsample': 0.8763237926509359}
# SCORE:
# 1.8391043256944262
# {'colsample_bytree': 0.7280844408887059, 'gamma': 0.3123836280245503, 'max_depth': 4.0, 'min_child_weight': 9.0, 'reg_alpha': 0.45190628881142864, 'reg_lambda': 0.5300645117164905, 'subsample': 0.9473646216348169}
# SCORE:
# 1.8135198085407265
# {'colsample_bytree': 0.9428386067915911, 'gamma': 0.4988896373588813, 'max_depth': 7.0, 'min_child_weight': 10.0, 'reg_alpha': 0.6040248086495794, 'reg_lambda': 0.42833118645224366, 'subsample': 0.9231975338084937}
# SCORE:
# 1.8588019637185524
# {'colsample_bytree': 0.7972044852121156, 'gamma': 0.29260651133767457, 'max_depth': 8.0, 'min_child_weight': 5.0, 'reg_alpha': 0.6845898730607367, 'reg_lambda': 0.6655334912203639, 'subsample': 0.8341566025537558}
# SCORE:
# 1.8897080438802416
# {'colsample_bytree': 0.8241759914104634, 'gamma': 0.2508558428613151, 'max_depth': 5.0, 'min_child_weight': 8.0, 'reg_alpha': 0.38012931187620014, 'reg_lambda': 0.583448083675014, 'subsample': 0.9674646566336154}
# SCORE:
# 1.8573829036583656
# {'colsample_bytree': 0.7693534768554606, 'gamma': 0.11275406436183794, 'max_depth': 4.0, 'min_child_weight': 6.0, 'reg_alpha': 0.2430771724433168, 'reg_lambda': 0.838902112305375, 'subsample': 0.9334675455638333}
# SCORE:
# 1.8122762171571791
# {'colsample_bytree': 0.7534019546558653, 'gamma': 0.46894020960516714, 'max_depth': 6.0, 'min_child_weight': 4.0, 'reg_alpha': 0.20672404295363322, 'reg_lambda': 0.703869880440779, 'subsample': 0.9006217233687056}
# SCORE:
# 1.8513784094273136
# {'colsample_bytree': 0.8081512304777716, 'gamma': 0.15511934939060976, 'max_depth': 10.0, 'min_child_weight': 7.0, 'reg_alpha': 0.30281755310907044, 'reg_lambda': 0.5492295707714351, 'subsample': 0.9106436135146757}
# SCORE:
# 1.8952690202414084
# {'colsample_bytree': 0.9197448896932647, 'gamma': 0.1328434040012819, 'max_depth': 13.0, 'min_child_weight': 3.0, 'reg_alpha': 0.16567588095390515, 'reg_lambda': 0.385639246715689, 'subsample': 0.9947464748184413}
# SCORE:
# 1.8928569484768678
# {'colsample_bytree': 0.8629449698370923, 'gamma': 0.33246182570534444, 'max_depth': 4.0, 'min_child_weight': 8.0, 'reg_alpha': 0.42393279858836175, 'reg_lambda': 0.3072469842351364, 'subsample': 0.8864877091769862}
# SCORE:
# 1.804435690860462
# {'colsample_bytree': 0.7897652374138537, 'gamma': 0.19716704312815175, 'max_depth': 5.0, 'min_child_weight': 5.0, 'reg_alpha': 0.2790440472438529, 'reg_lambda': 0.6216854601970436, 'subsample': 0.8480776048163308}
# SCORE:
# 1.8462113078255875
# {'colsample_bytree': 0.9601344948067367, 'gamma': 0.3561424329453959, 'max_depth': 9.0, 'min_child_weight': 9.0, 'reg_alpha': 0.5699115114018856, 'reg_lambda': 0.4375787011912445, 'subsample': 0.8580222481325536}
# SCORE:
# 1.9323962410503805
# {'colsample_bytree': 0.7603272913443022, 'gamma': 0.40067091172712455, 'max_depth': 7.0, 'min_child_weight': 6.0, 'reg_alpha': 0.626765219079032, 'reg_lambda': 0.7498734847231988, 'subsample': 0.977475670710376}
# SCORE:
# 1.8899450447088513
# {'colsample_bytree': 0.8414567817002508, 'gamma': 0.10006940269354105, 'max_depth': 8.0, 'min_child_weight': 7.0, 'reg_alpha': 0.33299091420024085, 'reg_lambda': 0.48797361793847077, 'subsample': 0.8191580492943924}
# SCORE:
# 1.951867277931712
# {'colsample_bytree': 0.8985911596878655, 'gamma': 0.2328797251093364, 'max_depth': 5.0, 'min_child_weight': 4.0, 'reg_alpha': 0.46344366932791864, 'reg_lambda': 0.19413426715906978, 'subsample': 0.9656597333515978}
# SCORE:
# 1.8415510190584448
# {'colsample_bytree': 0.8752246947437933, 'gamma': 0.2698779884179938, 'max_depth': 15.0, 'min_child_weight': 8.0, 'reg_alpha': 0.10668232495413282, 'reg_lambda': 0.2684719077359547, 'subsample': 0.9549552863538746}
# SCORE:
# 1.900748953859211
# {'colsample_bytree': 0.8836460101557647, 'gamma': 0.37685283489696414, 'max_depth': 12.0, 'min_child_weight': 10.0, 'reg_alpha': 0.37008060044848773, 'reg_lambda': 0.4722623729698452, 'subsample': 0.8321008785230108}
# SCORE:
# 1.9302565931339288
# {'colsample_bytree': 0.7795327436717728, 'gamma': 0.4267003333825844, 'max_depth': 4.0, 'min_child_weight': 9.0, 'reg_alpha': 0.7458851503169025, 'reg_lambda': 0.3573914928476921, 'subsample': 0.9255213296800021}
# SCORE:
# 1.7903244546901766
# {'colsample_bytree': 0.7835616128608737, 'gamma': 0.4903972162864186, 'max_depth': 6.0, 'min_child_weight': 10.0, 'reg_alpha': 0.7433090765885265, 'reg_lambda': 0.08753834958611341, 'subsample': 0.9901661661415246}
# SCORE:
# 1.852963013155211
# {'colsample_bytree': 0.7061744045408287, 'gamma': 0.4226145561008937, 'max_depth': 4.0, 'min_child_weight': 6.0, 'reg_alpha': 0.8844315673348475, 'reg_lambda': 0.362519482667814, 'subsample': 0.8476206064799842}
# SCORE:
# 1.825807537016498
# {'colsample_bytree': 0.7223396911233851, 'gamma': 0.44983171172622033, 'max_depth': 7.0, 'min_child_weight': 7.0, 'reg_alpha': 0.7024302278097286, 'reg_lambda': 0.23495434830248774, 'subsample': 0.9446380133709078}
# SCORE:
# 1.857987173149717
# {'colsample_bytree': 0.74674701848138, 'gamma': 0.46600540713957683, 'max_depth': 4.0, 'min_child_weight': 2.0, 'reg_alpha': 0.9646246723264711, 'reg_lambda': 0.1372210103730595, 'subsample': 0.9369713771715039}
# SCORE:
# 1.793907234986768
# 100%|███████████████████████████████████████████████| 100/100 [00:29<00:00,  3.39trial/s, best loss: 3.177887081300919]

# %%
def XG_Boost(df, num):
    X, y_hhb, y_hhbo2, y_ca, y_na = XY(df)
    
    # Split data
    X1_train, X1_test, y1_train, y1_test = train_test_split(X, y_hhb, test_size=0.2, shuffle=1234)
    X2_train, X2_test, y2_train, y2_test = train_test_split(X, y_hhbo2, test_size=0.2, shuffle=1234)
    X3_train, X3_test, y3_train, y3_test = train_test_split(X, y_ca, test_size=0.2, shuffle=1234)
    X4_train, X4_test, y4_train, y4_test = train_test_split(X, y_na, test_size=0.2, shuffle=1234)
    
    
    xg_reg_hbb = xgb.XGBRegressor(parameters=best_hhb)
    
    xg_reg_hbo2 = xgb.XGBRegressor(parameters=best_hbo2)
    
    xg_reg_ca = xgb.XGBRegressor(parameters=best_ca)
    
    xg_reg_na = xgb.XGBRegressor(parameters=best_na)
    
    xg_reg_hbb.fit(X1_train,y1_train)
    preds_hbb = xg_reg_hbb.predict(X1_test)

    xg_reg_hbo2.fit(X2_train,y2_train)
    preds_hbo2 = xg_reg_hbo2.predict(X2_test)

    xg_reg_ca.fit(X3_train,y3_train)
    preds_ca = xg_reg_ca.predict(X3_test)

    xg_reg_na.fit(X4_train,y4_train)
    preds_na = xg_reg_na.predict(X4_test)
    
    
    rmse_hbb = np.sqrt(mean_squared_error(y1_test, preds_hbb))
    rmse_hbo2 = np.sqrt(mean_squared_error(y2_test, preds_hbo2))
    rmse_ca = np.sqrt(mean_squared_error(y3_test, preds_ca))
    rmse_na = np.sqrt(mean_squared_error(y4_test, preds_na))

    print(num, " mm")
    print("RMSE - hbb  : %f" % (rmse_hbb))
    print("RMSE - hbo2 : %f" % (rmse_hbo2))
    print("RMSE - ca   : %f" % (rmse_ca))
    print("RMSE - na   : %f" % (rmse_na))
    
    
    return xg_reg_hbb, xg_reg_hbo2, xg_reg_ca, xg_reg_na

# %%
# data_rho_25, data_rho_20, data_rho_15, data_rho_10

hbb_25, hbo2_25, ca_25, na_25 = XG_Boost(data_rho_25, 25)

hbb_20, hbo2_20, ca_20, na_20 = XG_Boost(data_rho_20, 20)

hbb_15, hbo2_15, ca_15, na_15 = XG_Boost(data_rho_15, 15)

hbb_10, hbo2_10, ca_10, na_10 = XG_Boost(data_rho_10, 10)
# Out:
# [14:09:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:09:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:09:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:09:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 25  mm
# RMSE - hbb  : 1.440114
# RMSE - hbo2 : 0.840065
# RMSE - ca   : 2.657275
# RMSE - na   : 1.921076
# [14:10:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:10:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:10:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:10:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 20  mm
# RMSE - hbb  : 1.367592
# RMSE - hbo2 : 0.835751
# RMSE - ca   : 2.579431
# RMSE - na   : 1.793540
# [14:10:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:10:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:10:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:10:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 15  mm
# RMSE - hbb  : 1.428716
# RMSE - hbo2 : 0.855677
# RMSE - ca   : 2.484416
# RMSE - na   : 1.659544
# [14:10:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:10:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:10:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:10:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 10  mm
# RMSE - hbb  : 1.377497
# RMSE - hbo2 : 0.901228
# RMSE - ca   : 2.394575
# RMSE - na   : 1.548741

# %%
test = pd.read_csv("../Data/Biometric Data Analysis/test.csv").fillna(0)

# %%
test_rho_25 = test[test['rho'] == 25]
test_rho_20 = test[test['rho'] == 20]
test_rho_15 = test[test['rho'] == 15]
test_rho_10 = test[test['rho'] == 10]

# %%
def prediction(hbb, hbo2, ca, na, df):
    
    test = df.iloc[:, 1:]
    
    preds_hbb = hbb.predict(test)
    preds_hbo2 = hbo2.predict(test)
    preds_ca = ca.predict(test)
    preds_na = na.predict(test)
    
    df_1 = df.copy()
    
    df_1['hhb'] = preds_hbb
    df_1['hbo2'] = preds_hbo2
    df_1['ca'] = preds_ca
    df_1['na'] = preds_na
    
    return df_1

# %%
# test_rho_25 - hbb_25, hbo2_25, ca_25, na_25
# test_rho_20 - hbb_20, hbo2_20, ca_20, na_20
# test_rho_15 - hbb_15, hbo2_15, ca_15, na_15
# test_rho_10 - hbb_10, hbo2_10, ca_10, na_10

rho_25 = prediction(hbb_25, hbo2_25, ca_25, na_25, test_rho_25)
rho_20 = prediction(hbb_20, hbo2_20, ca_20, na_20, test_rho_20)
rho_15 = prediction(hbb_15, hbo2_15, ca_15, na_15, test_rho_15)
rho_10 = prediction(hbb_10, hbo2_10, ca_10, na_10, test_rho_10)

# %%
temp = pd.concat([rho_25, rho_20, rho_15, rho_10]).sort_values('id')
id = temp.id
temp = temp.iloc[:, -4:]

# %%
submission = pd.concat([id, temp], axis=1)
submission.to_csv("submission/06.csv")

# %%
submission.head()
# Out:
#       id        hhb      hbo2         ca        na
# 0  10000   8.532439  5.101151  10.130732  3.097250
# 1  10001   5.707074  4.179231   7.486853  2.767264
# 2  10002  10.141157  4.541951  11.031622  2.940061
# 3  10003   8.519643  3.921633   9.055074  3.404695
# 4  10004   5.722478  3.620933   8.215435  2.713413

# %%
# Out:
# 10000
