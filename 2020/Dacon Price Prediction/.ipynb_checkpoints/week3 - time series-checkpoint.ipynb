# %%
# delete negative value:
# 1. id와 amount의 절대값이 같은 값 찾기
# 1-1. 취소된 거래 전날 거래들 중 가장 최근 값을 선택
# 2. id와 amount의 절대 값이 없는 경우
# 2-1. 대부분의 취소 내역들이 2016년 8월 전 거래내역들에 대한 취소로 예상

# %%
import pandas as pd
import numpy as np

import matplotlib as mlp
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import datetime as dt

# %%
# 1등 코드에서는 test만 사용함.
test = pd.read_csv("../../Data/Price prediction/test.csv")
print("shape of the test:", test.shape)
# 8개의 feature
# Out:
# shape of the test: (473392, 8)

# %%
# datetime 타입으로 변경
test.date = pd.to_datetime(test.date)

# %%
temp = test.groupby(["store_id", "date"]).sum()
temp[temp['amount'] <0]

# 어떤 날들은 cancel 때문에 하루 매출 자체가 음수가 되는 경우도 있음.
# Out:
#                      amount  installments  days_of_week  holyday
# store_id date
# 1        2016-08-02   -2500           0.0             1        0
#          2017-08-28   -2500           0.0             0        0
#          2017-12-20   -2025           9.0             8        0
#          2018-02-09    -300           0.0             4        0
# 5        2017-06-14     -53           0.0             8        0
# 44       2017-07-08    -375           0.0            15        0
# 47       2018-03-11    -145           0.0             6        0
# 49       2017-12-22   -1275           0.0            20        0
# 57       2016-08-03    -675           0.0             4        0
# 67       2016-11-19   -1138           0.0            20        0
#          2017-06-24    -713           0.0            20        0
#          2017-08-23   -1320           2.0             2        0
# 73       2017-01-03     -75           0.0             3        0
# ...

# %% [markdown]
# 이 음수들을 제거하기 위해 카드 아이디를 이용하여 같은 카드의 negative transaction의 시간보다 작으면서 가장 최근 transaction 중
#
# 1) 절대값이 같은 양수 가격의 transaction 을 제거 혹은
#
# 2) 절대값이 더 큰 양수 가격의 transaction 에서 음수 transaction의 가격을 빼는 방법으로 음수들을 제거.

# %%
neg = test[test['amount'] < 0][['card_id', 'amount', 'date']]
neg_index = neg.index

# %%
"""def index_of_return(data):
    data = data.iloc[:, [3,4]]
    neg = data[data['amount'] < 0][['card_id', 'amount']]
    neg_index = neg.index

    index_temp = []
    
    for i in neg_index:
        neg_index_ = neg.index.get_loc(i)
        neg_id, neg_amount = neg.iloc[neg_index_].card_id, neg.iloc[neg_index_].amount
        
        temp = abs(data[(data['card_id'] == neg_id) & ((data['amount'] == -neg_amount))].index - i).min()
        index_temp.append(temp)
        print(i, temp)
        
    return index_temp"""

# %%
def index_change(neg_index):
    neg_index_ = []
    
    for i in neg_index:
        neg_index_.append(neg.index.get_loc(i))
        
    return neg_index_

def index_of_return(data):
    data = data.iloc[:, [1, 3,4]]
    neg = data[data['amount'] < 0][['card_id', 'amount', 'date']]
    neg_index = neg.index
    neg_index_ = index_change(neg_index)
    
    index_return = pd.DataFrame(index=neg_index, columns=["canceled_index"])
    
    for i, j in zip(neg_index, neg_index_):
        neg_index_ = neg.index.get_loc(i)
        neg_id, neg_amount = neg.iloc[neg_index_].card_id, neg.iloc[j].amount
        
        temp = abs(data[(data['card_id'] == neg_id) & ((data['amount'] == -neg_amount))].date - neg.iloc[j].date)
        
        if not temp.empty:
            index_return.iloc[j] = temp.idxmin()
        else:
            index_return.iloc[j] = np.NaN
            print("no matching value:", i)
               
    return index_return

# %%
index_test = index_of_return(test)
# 전체 중 3건의 환불내역이 거래내역과 일치하는 것이 없음
# test의 인덱스값
# Out:
# no matching value: 337285
# no matching value: 379999
# no matching value: 470609

# %%
index_test.index.name = 'neg'
index_test.columns = ['pos']
index_test.to_csv("canceled_index_test.csv") # 인덱스 값들을 저장

# %%
test_pos = pd.read_csv("canceled_index_test.csv")
test_pos.isnull().sum()
# 3개가 빔
# Out:
# neg    0
# pos    3
# dtype: int64

# %%
temp = test_pos['pos'].index[test_pos['pos'].apply(np.isnan)]
test_pos.iloc[temp]

# 각각의 해당 인덱스
# Out:
#          neg  pos
# 6945  337285  NaN
# 7266  379999  NaN
# 7904  470609  NaN

# %%
temp = test.iloc[test_pos.iloc[temp, 0]]
temp

# 취소 내역들이 2016 8월 1일 근처
# 2016년 8월 1일 전 거래를 취소한 것으로 추정
# Out:
#         store_id       date      time     card_id  amount  installments  \
# 337285       129 2016-08-02  19:41:37  a5180934ff   -1400           NaN
# 379999       153 2016-08-08  09:22:43  6a86be3194    -215           NaN
# 470609       196 2016-08-19  19:38:04  4deead4fa6    -750           NaN
#
#         days_of_week  holyday
# 337285             1        0
# 379999             0        0
# 470609             4        0

# %%
# 해당 인덱스(취소된 거래들) 데이터들 삭제 후 저장
neg = test_pos.neg
pos = test_pos.pos.dropna().astype(int)
temp = pd.concat([neg, pos])
test_ = test.drop(test.index[temp])
test_.to_csv("test_pos.csv", index=False)

# %%
# store_id별, date별로 저장
test = pd.read_csv("test_pos.csv")
test.date = pd.to_datetime(test.date)
data = test.groupby(['store_id', 'date'])[['amount']].sum()

# %%
# test의 최대 날짜는 2018년 3월 31일
test.date.max()
# Out:
# Timestamp('2018-03-31 00:00:00')

# %%
# last day: 2018-03-31
# 각 가게들의 마지막 open날짜와 예측해야할 날짜로부터의 날짜 계산

last_day = dt.datetime(2018,3,31)
interval = dt.timedelta(days=14)
store_names = data.index.get_level_values('store_id').unique()

temp =[]

for store_name in store_names:
    temp.append(last_day - data.loc[store_name].index[-1])
    
temp = pd.DataFrame(temp)
temp.iloc[:,0].value_counts()
# Out:
# 0 days     148
# 1 days      25
# 2 days       8
# 3 days       6
# 5 days       4
# 4 days       4
# 8 days       2
# 10 days      1
# 73 days      1
# 7 days       1
# Name: 0, dtype: int64

# %%
# 최대 날짜로 부터 73일 차이가 나는 가게가 있음.
# store_id: 197

temp = test[test['store_id']==197].copy()
temp['count'] = 1

temp = temp.groupby('date')[['amount', 'count']].sum()


# store_id: 197의 월별 매출 건 수
all_times = pd.date_range(test.date.min(),
                          test.date.max(), freq = "D")
temp = temp.reindex(all_times, fill_value=0)
temp.resample('M')[['count']].sum().plot()

#  (월에 최소 5일 이상 데이터가 있는 상점만을 문제에 포함.) -> 월 매출 5회 이하가 다반수.

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller, kpss

def ts_diagnostics(y, lags=None, title='', filename=''):
    '''
    Calculate acf, pacf, qq plot and Augmented Dickey Fuller test for a given time series
    '''
    if not isinstance(y, pd.Series):
        y = pd.Series(y)

    # weekly moving averages (5 day window because of workdays)
    rolling_mean = pd.Series.rolling(y, window=2).mean()
    rolling_std = pd.Series.rolling(y, window=2).std()

    fig = plt.figure(figsize=(14, 12))
    layout = (3, 2)
    ts_ax = plt.subplot2grid(layout, (0, 0), colspan=2)
    acf_ax = plt.subplot2grid(layout, (1, 0))
    pacf_ax = plt.subplot2grid(layout, (1, 1))
    qq_ax = plt.subplot2grid(layout, (2, 0))
    hist_ax = plt.subplot2grid(layout, (2, 1))

    # time series plot
    y.plot(ax=ts_ax)
    rolling_mean.plot(ax=ts_ax, color='crimson')
    rolling_std.plot(ax=ts_ax, color='darkslateblue')
    plt.legend(loc='best')
    ts_ax.set_title(title, fontsize=24)

    # acf and pacf
    plot_acf(y, lags=lags, ax=acf_ax, alpha=0.5)
    plot_pacf(y, lags=lags, ax=pacf_ax, alpha=0.5)

    # qq plot
    sm.qqplot(y, line='s', ax=qq_ax)
    qq_ax.set_title('QQ Plot')

    # hist plot
    y.plot(ax=hist_ax, kind='hist', bins=25)
    hist_ax.set_title('Histogram')
    plt.tight_layout()
    plt.show()

    # perform Augmented Dickey Fuller test
    print('Results of Dickey-Fuller test:')
    dftest = adfuller(y, autolag='AIC') # about adfuller: https://datascienceschool.net/view-notebook/ebb638fc880145b9adeef8dfa630f067/
                                        # https://www.statsmodels.org/dev/generated/statsmodels.tsa.stattools.adfuller.html
    dfoutput = pd.Series(dftest[0:4], index=['test statistic', 'p-value', '# of lags', '# of observations'])
    for key, value in dftest[4].items():
        dfoutput['Critical Value (%s)' % key] = value
    print(dfoutput)

# %%
ts_diagnostics(test[test['store_id']==0].amount)
# Out:
# No handles with labels found to put in legend.
# Results of Dickey-Fuller test:
# test statistic           -43.821643
# p-value                    0.000000
# # of lags                  1.000000
# # of observations       4185.000000
# Critical Value (1%)       -3.431914
# Critical Value (5%)       -2.862231
# Critical Value (10%)      -2.567138
# dtype: float64

# %%
# after log
ts_diagnostics(np.log(test[test['store_id']==0].amount))
# Out:
# No handles with labels found to put in legend.
# Results of Dickey-Fuller test:
# test statistic           -33.979188
# p-value                    0.000000
# # of lags                  2.000000
# # of observations       4184.000000
# Critical Value (1%)       -3.431914
# Critical Value (5%)       -2.862231
# Critical Value (10%)      -2.567138
# dtype: float64

# %%
ts_diagnostics(test[test['store_id']==39].amount)
# Out:
# No handles with labels found to put in legend.
# Results of Dickey-Fuller test:
# test statistic          -24.198692
# p-value                   0.000000
# # of lags                 0.000000
# # of observations       756.000000
# Critical Value (1%)      -3.439029
# Critical Value (5%)      -2.865371
# Critical Value (10%)     -2.568810
# dtype: float64

# %%
ts_diagnostics(np.log(test[test['store_id']==39].amount))
# Out:
# No handles with labels found to put in legend.
# Results of Dickey-Fuller test:
# test statistic          -24.143262
# p-value                   0.000000
# # of lags                 0.000000
# # of observations       756.000000
# Critical Value (1%)      -3.439029
# Critical Value (5%)      -2.865371
# Critical Value (10%)     -2.568810
# dtype: float64

# %%
ts_diagnostics(test[test['store_id']==123].amount)
# Out:
# No handles with labels found to put in legend.
# Results of Dickey-Fuller test:
# test statistic           -34.708620
# p-value                    0.000000
# # of lags                  0.000000
# # of observations       1197.000000
# Critical Value (1%)       -3.435825
# Critical Value (5%)       -2.863958
# Critical Value (10%)      -2.568057
# dtype: float64

# %%
# afger log
ts_diagnostics(np.log(test[test['store_id']==123].amount))
# Out:
# No handles with labels found to put in legend.
# Results of Dickey-Fuller test:
# test statistic           -34.868485
# p-value                    0.000000
# # of lags                  0.000000
# # of observations       1197.000000
# Critical Value (1%)       -3.435825
# Critical Value (5%)       -2.863958
# Critical Value (10%)      -2.568057
# dtype: float64

# %% [markdown]
# - [Autocorrelation](https://m.blog.naver.com/PostView.nhn?blogId=sw4r&logNo=221027713065&proxyReferer=https:%2F%2Fwww.google.com%2F): [wiki](https://en.wikipedia.org/wiki/Autocorrelation)
# - [Quantiles](https://blog.naver.com/PostView.nhn?blogId=sw4r&logNo=221026102874&parentCategoryNo=&categoryNo=117&viewDate=&isShowPopularPosts=true&from=search): [wiki](https://en.wikipedia.org/wiki/Quantile)
#
# ![](img01.png)

# %% [markdown]
# - 정규분포를 따르는 경우 QQ plot은 직선에 가깝다.
# - 정규분포를 통해 통계값을 추론을 할 수 있다 (train set이 많을 경우)

# %% [markdown]
# ### [Autocorrelation](https://www.youtube.com/watch?v=UFvDSX3jsYg)
# - http://econ22.hosting.paran.com/metric/Chap_11_rep.pdf
# -

# %%
df = test.copy()
test_groupby_date_store = df.groupby(['date', 'store_id'])['amount', 'holyday'].sum()
test_groupby_date_store = test_groupby_date_store.reset_index()

test_groupby_date_store = test_groupby_date_store.set_index('date')
store_list = test_groupby_date_store.store_id.unique()

store_list.sort()
# Out:
# C:\Users\lonj7\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
# SARIMAX: https://www.kaggle.com/poiupoiu/how-to-use-sarimax#SARIMA-model
import math
import scipy.stats as st
import itertools
from statsmodels.tsa.arima_model import ARIMA

def get_optimal_params(y):
    # Define the p, d and q parameters to take any value between 0 and 1

    param_dict = {}
    # pdq -> 000 100 010 001 110 101 011 111
    for param in pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(y,
                                            order=param,    # trial1: ARIMA, trial2: SARIMAX
                                            )           
            results = mod.fit()
            model = ARIMA(y, order=param)
            results_ARIMA = model.fit(disp=-1)
            results_ARIMA.summary()
            param_dict[results.aic] = param
        except:
            continue

    min_aic = min(param_dict.keys())
    optimal_params = param_dict[min_aic]
    return optimal_params

# %%
sampling_p = 28
mean_period = 2 * 3 #14 * 2*3

predic_len = math.floor(100 / sampling_p)

expected_return_pct_lending = 0.13 * (100 + 16 + 6.8) / 365    # ???
expected_loss_pct_lending = 1.00
optimal_prob = expected_loss_pct_lending / (expected_loss_pct_lending + expected_return_pct_lending)
optimal_z_score = st.norm.ppf(optimal_prob)

min_period = 6


max_pdq = 2
p = d = q = range(0, max_pdq)
pdq = list(itertools.product(p, d, q))

# %%
submission = pd.read_csv("../../Data/Price Prediction/submission.csv")

pdqs = dict()
print(optimal_prob)
print(optimal_z_score)
output_file_name_fmt = 'submission_week3_SARIMAX.csv'
output_file_name = output_file_name_fmt.format(optimal_p=round(optimal_prob, 4),
                                               sampling_period=sampling_p,
                                               mean_period=mean_period,
                                               min_period=min_period,
                                               max_pdq=max_pdq)

submission_copy = submission.copy()
# Out:
# 0.9580957780787686
# 1.7290036387221377

# %%
def arima_main(input_df, sampling_period_days, fcst_period):
    
    # resample: sampling_period_days
    input_df = input_df[len(input_df) % sampling_period_days:].resample(str(sampling_period_days) + 'D').sum()
    
    # when  amount == 0 (total amount of day)
    prob_of_no_sales = len(input_df[(input_df.amount == 0) | (input_df.amount.isna())]) / len(input_df)
    ts_log = np.log(input_df.amount)
    ts_log = ts_log[~ts_log.isin([np.nan, np.inf, -np.inf])]

    # 산식 E(return) == 0.13 (100 + x) / 365
    # 위의 E(return)안의 x값을 늘려 optimal p를 조절하는 방식으로 예측에서 빠진 기간동안의 매출을 채우기로 결정. 
    # 28일씩 리샘플링한 경우는 (84일 예측) x==22.8, 
    # 14일씩 리샘플링한 경우는 (98일 예측) x == 30 (30 이상은 test 해보지 않음)으로 했을 경우 좋은 결과가 나왔음
    
    if len(ts_log) < min_period: # min_period = 6
        return None
    
    if sampling_period_days >= 28:                                    # sampling period: 28days
        expected_return_pct_lending = 0.13 * (100 + 16 + 6.8) / 365   # ???
    elif sampling_period_days >= 14:                                  # sampling period: 14days
        expected_return_pct_lending = 0.13 * (100 + 16 + 14) / 365
    elif sampling_period_days >= 7:                                   # sampling period: 7days (추가)
        expected_return_pct_lending = 0.13 * (100 + 16 + 14) / 365     
    else:                                                             # sampling period: under 7days or X
        expected_return_pct_lending = 0.13 * (100 + 16 + 6.8) / 365

    expected_loss_pct_lending = 1.00
    optimal_prob = expected_loss_pct_lending / (expected_loss_pct_lending + expected_return_pct_lending)
    optimal_z_score = st.norm.ppf(optimal_prob)

    optimal_params = get_optimal_params(ts_log)
    pdqs[store_i] = optimal_params

    model = ARIMA(ts_log, order=optimal_params)
    results_ARIMA = model.fit(disp=-1)
    fcst = results_ARIMA.forecast(fcst_period) # forcast period: sampling with 28days: 3
                                               #                 sampling with 14days: 7
                                               #                 sampling with 7 days: 7
                                               #                 sampling with X     : 

    fcst_means = fcst[0]
    fcst_stds = fcst[1]
    fcst_i = fcst_means - (fcst_stds * optimal_z_score)
    fcst_i = sum(map(lambda x: np.exp(x) if np.exp(x) > 0 else 0, fcst_i)) # log -> original
    prediction_i = fcst_i * (1 - prob_of_no_sales)
    return prediction_i

# %%
for store_i in store_list[:]:
    prediction_i = None
    test_df = test_groupby_date_store[test_groupby_date_store.store_id == store_i]
    test_df_daily = test_df.resample('D').sum()
    prediction_i = arima_main(test_df_daily, sampling_period_days=28, fcst_period=3)
    # if prediction_i is None:
    #     prediction_i = arima_main(test_df_daily, sampling_period_days=21, fcst_period=4)
    if prediction_i is None:
        prediction_i = arima_main(test_df_daily, sampling_period_days=14, fcst_period=7)
    if prediction_i is None:
        prediction_i = arima_main(test_df_daily, sampling_period_days=7, fcst_period=12)
    if prediction_i is None:
        test_df = test_df_daily[len(test_df_daily) % 14:].resample('14D').sum()

        prob_of_no_sales = len(test_df[(test_df.amount == 0) | (test_df.amount.isna())]) / len(test_df)
        ts_log = ts_log[~ts_log.isin([np.nan, np.inf, -np.inf])]
        ts_log_wkly = np.log(test_df.amount)

        estimated_amt = np.exp(ts_log_wkly.mean() - ts_log_wkly.std() * optimal_z_score) * (1 - prob_of_no_sales)
        prediction_i = estimated_amt * mean_period

    submission_copy.loc[submission_copy['store_id'] == store_i, 'total_sales'] = prediction_i

submission_copy.to_csv(output_file_name, index=False)

print(output_file_name)
# Out:
# C:\Users\lonj7\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\lonj7\Anaconda3\lib\site-packages\statsmodels\tsa\kalmanf\kalmanfilter.py:220: RuntimeWarning: divide by zero encountered in true_divide
#   Z_mat, R_mat, T_mat)
# C:\Users\lonj7\Anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:689: RuntimeWarning: overflow encountered in exp
#   newparams = ((1-np.exp(-params))/(1+np.exp(-params))).copy()
# C:\Users\lonj7\Anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:689: RuntimeWarning: invalid value encountered in true_divide
#   newparams = ((1-np.exp(-params))/(1+np.exp(-params))).copy()
# C:\Users\lonj7\Anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:690: RuntimeWarning: overflow encountered in exp
#   tmp = ((1-np.exp(-params))/(1+np.exp(-params))).copy()
# ...

# %%
# 점수: 65314.2137607074
