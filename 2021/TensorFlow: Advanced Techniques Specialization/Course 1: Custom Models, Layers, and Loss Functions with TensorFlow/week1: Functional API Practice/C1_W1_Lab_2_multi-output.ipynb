# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Get the data from UCI dataset
URL = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00242/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URL)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 1ms/sample - loss: 307.0324 - y1_output_loss: 140.1852 - y2_output_loss: 164.5424 - y1_output_root_mean_squared_error: 11.8841 - y2_output_root_mean_squared_error: 12.8764 - val_loss: 68.6353 - val_y1_output_loss: 17.9900 - val_y2_output_loss: 48.9071 - val_y1_output_root_mean_squared_error: 4.3080 - val_y2_output_root_mean_squared_error: 7.0765
# Epoch 2/500
# 614/614 [==============================] - 0s 145us/sample - loss: 31.0831 - y1_output_loss: 12.8639 - y2_output_loss: 18.1138 - y1_output_root_mean_squared_error: 3.5836 - y2_output_root_mean_squared_error: 4.2709 - val_loss: 21.4813 - val_y1_output_loss: 8.8271 - val_y2_output_loss: 11.9892 - val_y1_output_root_mean_squared_error: 3.0208 - val_y2_output_root_mean_squared_error: 3.5151
# Epoch 3/500
# 614/614 [==============================] - 0s 156us/sample - loss: 26.5140 - y1_output_loss: 10.2728 - y2_output_loss: 16.4907 - y1_output_root_mean_squared_error: 3.1979 - y2_output_root_mean_squared_error: 4.0358 - val_loss: 21.7005 - val_y1_output_loss: 8.0477 - val_y2_output_loss: 13.2531 - val_y1_output_root_mean_squared_error: 2.8834 - val_y2_output_root_mean_squared_error: 3.6587
# Epoch 4/500
# 614/614 [==============================] - 0s 143us/sample - loss: 22.8994 - y1_output_loss: 9.2010 - y2_output_loss: 13.6218 - y1_output_root_mean_squared_error: 3.0340 - y2_output_root_mean_squared_error: 3.7006 - val_loss: 21.5729 - val_y1_output_loss: 7.3361 - val_y2_output_loss: 13.6476 - val_y1_output_root_mean_squared_error: 2.7527 - val_y2_output_root_mean_squared_error: 3.7411
# Epoch 5/500
# 614/614 [==============================] - 0s 151us/sample - loss: 23.3673 - y1_output_loss: 9.3057 - y2_output_loss: 14.1265 - y1_output_root_mean_squared_error: 3.0489 - y2_output_root_mean_squared_error: 3.7512 - val_loss: 30.3658 - val_y1_output_loss: 10.1996 - val_y2_output_loss: 19.4357 - val_y1_output_root_mean_squared_error: 3.2378 - val_y2_output_root_mean_squared_error: 4.4590
# Epoch 6/500
# 614/614 [==============================] - 0s 136us/sample - loss: 25.4086 - y1_output_loss: 9.5560 - y2_output_loss: 15.8805 - y1_output_root_mean_squared_error: 3.0851 - y2_output_root_mean_squared_error: 3.9863 - val_loss: 24.0308 - val_y1_output_loss: 9.4556 - val_y2_output_loss: 13.8148 - val_y1_output_root_mean_squared_error: 3.1268 - val_y2_output_root_mean_squared_error: 3.7754
# Epoch 7/500
# 614/614 [==============================] - 0s 132us/sample - loss: 32.3827 - y1_output_loss: 10.8779 - y2_output_loss: 21.6219 - y1_output_root_mean_squared_error: 3.2854 - y2_output_root_mean_squared_error: 4.6463 - val_loss: 31.8086 - val_y1_output_loss: 6.9875 - val_y2_output_loss: 24.0203 - val_y1_output_root_mean_squared_error: 2.6910 - val_y2_output_root_mean_squared_error: 4.9565
# Epoch 8/500
# 614/614 [==============================] - 0s 156us/sample - loss: 23.2917 - y1_output_loss: 8.6402 - y2_output_loss: 14.6903 - y1_output_root_mean_squared_error: 2.9312 - y2_output_root_mean_squared_error: 3.8341 - val_loss: 29.2024 - val_y1_output_loss: 8.2465 - val_y2_output_loss: 20.2457 - val_y1_output_root_mean_squared_error: 2.9145 - val_y2_output_root_mean_squared_error: 4.5506
# Epoch 9/500
# 614/614 [==============================] - 0s 137us/sample - loss: 20.8373 - y1_output_loss: 8.4838 - y2_output_loss: 12.5955 - y1_output_root_mean_squared_error: 2.9066 - y2_output_root_mean_squared_error: 3.5198 - val_loss: 40.7700 - val_y1_output_loss: 10.1166 - val_y2_output_loss: 30.3578 - val_y1_output_root_mean_squared_error: 3.2148 - val_y2_output_root_mean_squared_error: 5.5168
# Epoch 10/500
# 614/614 [==============================] - 0s 138us/sample - loss: 24.1860 - y1_output_loss: 8.7824 - y2_output_loss: 15.2359 - y1_output_root_mean_squared_error: 2.9742 - y2_output_root_mean_squared_error: 3.9167 - val_loss: 14.7642 - val_y1_output_loss: 6.4477 - val_y2_output_loss: 7.8432 - val_y1_output_root_mean_squared_error: 2.5854 - val_y2_output_root_mean_squared_error: 2.8425
# Epoch 11/500
# 614/614 [==============================] - 0s 147us/sample - loss: 19.2479 - y1_output_loss: 7.4742 - y2_output_loss: 12.0742 - y1_output_root_mean_squared_error: 2.7166 - y2_output_root_mean_squared_error: 3.4450 - val_loss: 16.5649 - val_y1_output_loss: 6.5075 - val_y2_output_loss: 9.6444 - val_y1_output_root_mean_squared_error: 2.5963 - val_y2_output_root_mean_squared_error: 3.1344
# Epoch 12/500
# 614/614 [==============================] - 0s 134us/sample - loss: 19.4466 - y1_output_loss: 7.5508 - y2_output_loss: 11.8027 - y1_output_root_mean_squared_error: 2.7526 - y2_output_root_mean_squared_error: 3.4452 - val_loss: 20.6848 - val_y1_output_loss: 8.1810 - val_y2_output_loss: 11.8274 - val_y1_output_root_mean_squared_error: 2.9092 - val_y2_output_root_mean_squared_error: 3.4959
# Epoch 13/500
# 614/614 [==============================] - 0s 134us/sample - loss: 21.0644 - y1_output_loss: 7.9851 - y2_output_loss: 13.0469 - y1_output_root_mean_squared_error: 2.8220 - y2_output_root_mean_squared_error: 3.6195 - val_loss: 23.9808 - val_y1_output_loss: 7.2673 - val_y2_output_loss: 15.9882 - val_y1_output_root_mean_squared_error: 2.7426 - val_y2_output_root_mean_squared_error: 4.0570
# Epoch 14/500
# 614/614 [==============================] - 0s 141us/sample - loss: 16.8154 - y1_output_loss: 6.5942 - y2_output_loss: 10.2196 - y1_output_root_mean_squared_error: 2.5577 - y2_output_root_mean_squared_error: 3.2053 - val_loss: 14.8760 - val_y1_output_loss: 6.5676 - val_y2_output_loss: 7.8417 - val_y1_output_root_mean_squared_error: 2.6069 - val_y2_output_root_mean_squared_error: 2.8425
# Epoch 15/500
# 614/614 [==============================] - 0s 141us/sample - loss: 17.8445 - y1_output_loss: 6.9551 - y2_output_loss: 10.8958 - y1_output_root_mean_squared_error: 2.6292 - y2_output_root_mean_squared_error: 3.3063 - val_loss: 25.5886 - val_y1_output_loss: 9.7055 - val_y2_output_loss: 15.6000 - val_y1_output_root_mean_squared_error: 3.1419 - val_y2_output_root_mean_squared_error: 3.9644
# Epoch 16/500
# 614/614 [==============================] - 0s 146us/sample - loss: 26.3629 - y1_output_loss: 8.4377 - y2_output_loss: 17.6916 - y1_output_root_mean_squared_error: 2.9180 - y2_output_root_mean_squared_error: 4.2247 - val_loss: 14.3656 - val_y1_output_loss: 5.8697 - val_y2_output_loss: 8.0396 - val_y1_output_root_mean_squared_error: 2.4637 - val_y2_output_root_mean_squared_error: 2.8802
# Epoch 17/500
# 614/614 [==============================] - 0s 138us/sample - loss: 18.3696 - y1_output_loss: 6.7010 - y2_output_loss: 11.6028 - y1_output_root_mean_squared_error: 2.5915 - y2_output_root_mean_squared_error: 3.4138 - val_loss: 27.6149 - val_y1_output_loss: 9.7352 - val_y2_output_loss: 17.4889 - val_y1_output_root_mean_squared_error: 3.1502 - val_y2_output_root_mean_squared_error: 4.2061
# Epoch 18/500
# 614/614 [==============================] - 0s 132us/sample - loss: 16.3028 - y1_output_loss: 6.0181 - y2_output_loss: 10.2171 - y1_output_root_mean_squared_error: 2.4622 - y2_output_root_mean_squared_error: 3.2000 - val_loss: 13.3518 - val_y1_output_loss: 5.5214 - val_y2_output_loss: 7.3795 - val_y1_output_root_mean_squared_error: 2.3859 - val_y2_output_root_mean_squared_error: 2.7676
# Epoch 19/500
# 614/614 [==============================] - 0s 132us/sample - loss: 16.2188 - y1_output_loss: 6.0240 - y2_output_loss: 10.1388 - y1_output_root_mean_squared_error: 2.4643 - y2_output_root_mean_squared_error: 3.1853 - val_loss: 20.6225 - val_y1_output_loss: 6.3535 - val_y2_output_loss: 13.6370 - val_y1_output_root_mean_squared_error: 2.5660 - val_y2_output_root_mean_squared_error: 3.7468
# Epoch 20/500
# 614/614 [==============================] - 0s 144us/sample - loss: 14.6179 - y1_output_loss: 5.4381 - y2_output_loss: 9.0662 - y1_output_root_mean_squared_error: 2.3398 - y2_output_root_mean_squared_error: 3.0238 - val_loss: 11.8928 - val_y1_output_loss: 4.7521 - val_y2_output_loss: 6.7288 - val_y1_output_root_mean_squared_error: 2.2181 - val_y2_output_root_mean_squared_error: 2.6406
# Epoch 21/500
# 614/614 [==============================] - 0s 134us/sample - loss: 17.4529 - y1_output_loss: 6.3357 - y2_output_loss: 11.1077 - y1_output_root_mean_squared_error: 2.5113 - y2_output_root_mean_squared_error: 3.3386 - val_loss: 16.5148 - val_y1_output_loss: 5.6896 - val_y2_output_loss: 10.4990 - val_y1_output_root_mean_squared_error: 2.4109 - val_y2_output_root_mean_squared_error: 3.2715
# Epoch 22/500
# 614/614 [==============================] - 0s 134us/sample - loss: 14.1869 - y1_output_loss: 5.2941 - y2_output_loss: 8.9248 - y1_output_root_mean_squared_error: 2.2848 - y2_output_root_mean_squared_error: 2.9944 - val_loss: 21.8727 - val_y1_output_loss: 8.2286 - val_y2_output_loss: 13.2909 - val_y1_output_root_mean_squared_error: 2.8885 - val_y2_output_root_mean_squared_error: 3.6783
# Epoch 23/500
# 614/614 [==============================] - 0s 140us/sample - loss: 12.2330 - y1_output_loss: 4.8863 - y2_output_loss: 7.5435 - y1_output_root_mean_squared_error: 2.1820 - y2_output_root_mean_squared_error: 2.7334 - val_loss: 12.3520 - val_y1_output_loss: 4.4372 - val_y2_output_loss: 7.5531 - val_y1_output_root_mean_squared_error: 2.1391 - val_y2_output_root_mean_squared_error: 2.7886
# Epoch 24/500
# 614/614 [==============================] - 0s 135us/sample - loss: 10.7825 - y1_output_loss: 4.1694 - y2_output_loss: 6.5215 - y1_output_root_mean_squared_error: 2.0508 - y2_output_root_mean_squared_error: 2.5645 - val_loss: 9.5852 - val_y1_output_loss: 3.9572 - val_y2_output_loss: 5.2903 - val_y1_output_root_mean_squared_error: 2.0221 - val_y2_output_root_mean_squared_error: 2.3444
# Epoch 25/500
# 614/614 [==============================] - 0s 136us/sample - loss: 12.4305 - y1_output_loss: 4.4644 - y2_output_loss: 8.0245 - y1_output_root_mean_squared_error: 2.1079 - y2_output_root_mean_squared_error: 2.8262 - val_loss: 9.3565 - val_y1_output_loss: 3.9710 - val_y2_output_loss: 5.0936 - val_y1_output_root_mean_squared_error: 2.0206 - val_y2_output_root_mean_squared_error: 2.2965
# Epoch 26/500
# 614/614 [==============================] - 0s 141us/sample - loss: 10.0824 - y1_output_loss: 3.8707 - y2_output_loss: 6.1366 - y1_output_root_mean_squared_error: 1.9748 - y2_output_root_mean_squared_error: 2.4865 - val_loss: 10.2026 - val_y1_output_loss: 3.6406 - val_y2_output_loss: 6.2635 - val_y1_output_root_mean_squared_error: 1.9403 - val_y2_output_root_mean_squared_error: 2.5373
# Epoch 27/500
# 614/614 [==============================] - 0s 148us/sample - loss: 11.3540 - y1_output_loss: 4.0810 - y2_output_loss: 7.2512 - y1_output_root_mean_squared_error: 2.0125 - y2_output_root_mean_squared_error: 2.7026 - val_loss: 8.7138 - val_y1_output_loss: 3.8508 - val_y2_output_loss: 4.5523 - val_y1_output_root_mean_squared_error: 1.9969 - val_y2_output_root_mean_squared_error: 2.1740
# Epoch 28/500
# 614/614 [==============================] - 0s 135us/sample - loss: 11.5186 - y1_output_loss: 4.1760 - y2_output_loss: 7.3279 - y1_output_root_mean_squared_error: 2.0471 - y2_output_root_mean_squared_error: 2.7070 - val_loss: 8.7071 - val_y1_output_loss: 3.6838 - val_y2_output_loss: 4.8649 - val_y1_output_root_mean_squared_error: 1.9289 - val_y2_output_root_mean_squared_error: 2.2330
# Epoch 29/500
# 614/614 [==============================] - 0s 136us/sample - loss: 9.0206 - y1_output_loss: 3.4128 - y2_output_loss: 5.6810 - y1_output_root_mean_squared_error: 1.8434 - y2_output_root_mean_squared_error: 2.3712 - val_loss: 10.3476 - val_y1_output_loss: 4.0177 - val_y2_output_loss: 5.9799 - val_y1_output_root_mean_squared_error: 2.0409 - val_y2_output_root_mean_squared_error: 2.4864
# Epoch 30/500
# 614/614 [==============================] - 0s 132us/sample - loss: 9.0766 - y1_output_loss: 3.0741 - y2_output_loss: 6.1622 - y1_output_root_mean_squared_error: 1.7383 - y2_output_root_mean_squared_error: 2.4607 - val_loss: 11.2876 - val_y1_output_loss: 3.4347 - val_y2_output_loss: 7.4942 - val_y1_output_root_mean_squared_error: 1.8846 - val_y2_output_root_mean_squared_error: 2.7813
# Epoch 31/500
# 614/614 [==============================] - 0s 167us/sample - loss: 9.1968 - y1_output_loss: 3.0921 - y2_output_loss: 6.1324 - y1_output_root_mean_squared_error: 1.7602 - y2_output_root_mean_squared_error: 2.4695 - val_loss: 9.5449 - val_y1_output_loss: 3.4966 - val_y2_output_loss: 5.7688 - val_y1_output_root_mean_squared_error: 1.8974 - val_y2_output_root_mean_squared_error: 2.4382
# Epoch 32/500
# 614/614 [==============================] - 0s 132us/sample - loss: 8.0699 - y1_output_loss: 2.7447 - y2_output_loss: 5.3083 - y1_output_root_mean_squared_error: 1.6603 - y2_output_root_mean_squared_error: 2.3051 - val_loss: 7.3557 - val_y1_output_loss: 2.6077 - val_y2_output_loss: 4.5215 - val_y1_output_root_mean_squared_error: 1.6438 - val_y2_output_root_mean_squared_error: 2.1572
# Epoch 33/500
# 614/614 [==============================] - 0s 132us/sample - loss: 9.9397 - y1_output_loss: 3.2715 - y2_output_loss: 6.6501 - y1_output_root_mean_squared_error: 1.8097 - y2_output_root_mean_squared_error: 2.5816 - val_loss: 11.7984 - val_y1_output_loss: 4.0209 - val_y2_output_loss: 7.3965 - val_y1_output_root_mean_squared_error: 2.0312 - val_y2_output_root_mean_squared_error: 2.7700
# Epoch 34/500
# 614/614 [==============================] - 0s 133us/sample - loss: 9.8830 - y1_output_loss: 3.1695 - y2_output_loss: 6.6848 - y1_output_root_mean_squared_error: 1.7820 - y2_output_root_mean_squared_error: 2.5899 - val_loss: 6.7699 - val_y1_output_loss: 2.8183 - val_y2_output_loss: 3.8392 - val_y1_output_root_mean_squared_error: 1.6877 - val_y2_output_root_mean_squared_error: 1.9803
# Epoch 35/500
# 614/614 [==============================] - 0s 135us/sample - loss: 7.5596 - y1_output_loss: 2.6263 - y2_output_loss: 5.0939 - y1_output_root_mean_squared_error: 1.5941 - y2_output_root_mean_squared_error: 2.2402 - val_loss: 47.7509 - val_y1_output_loss: 15.5774 - val_y2_output_loss: 32.9179 - val_y1_output_root_mean_squared_error: 3.9221 - val_y2_output_root_mean_squared_error: 5.6893
# Epoch 36/500
# 614/614 [==============================] - 0s 140us/sample - loss: 13.3479 - y1_output_loss: 4.1766 - y2_output_loss: 9.1976 - y1_output_root_mean_squared_error: 2.0290 - y2_output_root_mean_squared_error: 3.0383 - val_loss: 7.3984 - val_y1_output_loss: 2.7660 - val_y2_output_loss: 4.4720 - val_y1_output_root_mean_squared_error: 1.6682 - val_y2_output_root_mean_squared_error: 2.1484
# Epoch 37/500
# 614/614 [==============================] - 0s 138us/sample - loss: 6.8030 - y1_output_loss: 2.2400 - y2_output_loss: 4.5189 - y1_output_root_mean_squared_error: 1.5021 - y2_output_root_mean_squared_error: 2.1323 - val_loss: 6.3111 - val_y1_output_loss: 2.2597 - val_y2_output_loss: 3.8274 - val_y1_output_root_mean_squared_error: 1.5285 - val_y2_output_root_mean_squared_error: 1.9936
# Epoch 38/500
# 614/614 [==============================] - 0s 134us/sample - loss: 8.6155 - y1_output_loss: 2.6106 - y2_output_loss: 5.9540 - y1_output_root_mean_squared_error: 1.6171 - y2_output_root_mean_squared_error: 2.4496 - val_loss: 6.2310 - val_y1_output_loss: 2.1515 - val_y2_output_loss: 3.8655 - val_y1_output_root_mean_squared_error: 1.4896 - val_y2_output_root_mean_squared_error: 2.0030
# Epoch 39/500
# 614/614 [==============================] - 0s 148us/sample - loss: 10.5303 - y1_output_loss: 3.3115 - y2_output_loss: 7.1382 - y1_output_root_mean_squared_error: 1.8270 - y2_output_root_mean_squared_error: 2.6819 - val_loss: 7.5424 - val_y1_output_loss: 2.2571 - val_y2_output_loss: 5.0596 - val_y1_output_root_mean_squared_error: 1.5238 - val_y2_output_root_mean_squared_error: 2.2849
# Epoch 40/500
# 614/614 [==============================] - 0s 142us/sample - loss: 7.9457 - y1_output_loss: 2.3947 - y2_output_loss: 5.5164 - y1_output_root_mean_squared_error: 1.5532 - y2_output_root_mean_squared_error: 2.3523 - val_loss: 7.3557 - val_y1_output_loss: 2.6715 - val_y2_output_loss: 4.4413 - val_y1_output_root_mean_squared_error: 1.6568 - val_y2_output_root_mean_squared_error: 2.1472
# Epoch 41/500
# 614/614 [==============================] - 0s 147us/sample - loss: 6.8152 - y1_output_loss: 2.1500 - y2_output_loss: 4.6872 - y1_output_root_mean_squared_error: 1.4606 - y2_output_root_mean_squared_error: 2.1637 - val_loss: 6.3416 - val_y1_output_loss: 1.8920 - val_y2_output_loss: 4.2976 - val_y1_output_root_mean_squared_error: 1.3881 - val_y2_output_root_mean_squared_error: 2.1011
# Epoch 42/500
# 614/614 [==============================] - 0s 136us/sample - loss: 7.3824 - y1_output_loss: 2.3578 - y2_output_loss: 5.0194 - y1_output_root_mean_squared_error: 1.5328 - y2_output_root_mean_squared_error: 2.2434 - val_loss: 12.5974 - val_y1_output_loss: 3.9114 - val_y2_output_loss: 8.2944 - val_y1_output_root_mean_squared_error: 2.0094 - val_y2_output_root_mean_squared_error: 2.9257
# Epoch 43/500
# 614/614 [==============================] - 0s 135us/sample - loss: 5.7389 - y1_output_loss: 1.8564 - y2_output_loss: 3.9385 - y1_output_root_mean_squared_error: 1.3509 - y2_output_root_mean_squared_error: 1.9784 - val_loss: 14.2361 - val_y1_output_loss: 4.2359 - val_y2_output_loss: 9.8203 - val_y1_output_root_mean_squared_error: 2.0660 - val_y2_output_root_mean_squared_error: 3.1572
# Epoch 44/500
# 614/614 [==============================] - 0s 156us/sample - loss: 7.4722 - y1_output_loss: 2.4559 - y2_output_loss: 5.0172 - y1_output_root_mean_squared_error: 1.5524 - y2_output_root_mean_squared_error: 2.2499 - val_loss: 6.9066 - val_y1_output_loss: 1.8652 - val_y2_output_loss: 5.0159 - val_y1_output_root_mean_squared_error: 1.3635 - val_y2_output_root_mean_squared_error: 2.2467
# Epoch 45/500
# 614/614 [==============================] - 0s 146us/sample - loss: 6.7247 - y1_output_loss: 1.8509 - y2_output_loss: 4.8345 - y1_output_root_mean_squared_error: 1.3639 - y2_output_root_mean_squared_error: 2.2056 - val_loss: 6.1589 - val_y1_output_loss: 1.8132 - val_y2_output_loss: 4.1590 - val_y1_output_root_mean_squared_error: 1.3680 - val_y2_output_root_mean_squared_error: 2.0706
# Epoch 46/500
# 614/614 [==============================] - 0s 157us/sample - loss: 5.5462 - y1_output_loss: 1.6750 - y2_output_loss: 3.9339 - y1_output_root_mean_squared_error: 1.2842 - y2_output_root_mean_squared_error: 1.9741 - val_loss: 8.4833 - val_y1_output_loss: 3.4886 - val_y2_output_loss: 4.7447 - val_y1_output_root_mean_squared_error: 1.8944 - val_y2_output_root_mean_squared_error: 2.2124
# Epoch 47/500
# 614/614 [==============================] - 0s 141us/sample - loss: 5.9515 - y1_output_loss: 1.7458 - y2_output_loss: 4.1980 - y1_output_root_mean_squared_error: 1.3183 - y2_output_root_mean_squared_error: 2.0527 - val_loss: 6.9870 - val_y1_output_loss: 1.9504 - val_y2_output_loss: 4.8344 - val_y1_output_root_mean_squared_error: 1.4173 - val_y2_output_root_mean_squared_error: 2.2312
# Epoch 48/500
# 614/614 [==============================] - 0s 156us/sample - loss: 6.8507 - y1_output_loss: 1.9608 - y2_output_loss: 4.8932 - y1_output_root_mean_squared_error: 1.4000 - y2_output_root_mean_squared_error: 2.2115 - val_loss: 11.0957 - val_y1_output_loss: 2.6156 - val_y2_output_loss: 8.2399 - val_y1_output_root_mean_squared_error: 1.6355 - val_y2_output_root_mean_squared_error: 2.9018
# Epoch 49/500
# 614/614 [==============================] - 0s 137us/sample - loss: 5.0376 - y1_output_loss: 1.4250 - y2_output_loss: 3.6011 - y1_output_root_mean_squared_error: 1.1884 - y2_output_root_mean_squared_error: 1.9040 - val_loss: 4.7147 - val_y1_output_loss: 1.6428 - val_y2_output_loss: 2.9372 - val_y1_output_root_mean_squared_error: 1.2932 - val_y2_output_root_mean_squared_error: 1.7442
# Epoch 50/500
# 614/614 [==============================] - 0s 136us/sample - loss: 11.8426 - y1_output_loss: 3.5971 - y2_output_loss: 8.2050 - y1_output_root_mean_squared_error: 1.9042 - y2_output_root_mean_squared_error: 2.8665 - val_loss: 7.7983 - val_y1_output_loss: 1.4049 - val_y2_output_loss: 6.3011 - val_y1_output_root_mean_squared_error: 1.1931 - val_y2_output_root_mean_squared_error: 2.5248
# Epoch 51/500
# 614/614 [==============================] - 0s 138us/sample - loss: 5.4497 - y1_output_loss: 1.7119 - y2_output_loss: 3.7611 - y1_output_root_mean_squared_error: 1.3056 - y2_output_root_mean_squared_error: 1.9352 - val_loss: 4.9913 - val_y1_output_loss: 1.4085 - val_y2_output_loss: 3.4279 - val_y1_output_root_mean_squared_error: 1.2038 - val_y2_output_root_mean_squared_error: 1.8820
# Epoch 52/500
# 614/614 [==============================] - 0s 156us/sample - loss: 5.5459 - y1_output_loss: 1.4686 - y2_output_loss: 4.1629 - y1_output_root_mean_squared_error: 1.2163 - y2_output_root_mean_squared_error: 2.0166 - val_loss: 4.1467 - val_y1_output_loss: 1.2739 - val_y2_output_loss: 2.7723 - val_y1_output_root_mean_squared_error: 1.1430 - val_y2_output_root_mean_squared_error: 1.6853
# Epoch 53/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.7506 - y1_output_loss: 1.3971 - y2_output_loss: 3.3538 - y1_output_root_mean_squared_error: 1.1795 - y2_output_root_mean_squared_error: 1.8329 - val_loss: 5.4400 - val_y1_output_loss: 1.5450 - val_y2_output_loss: 3.7694 - val_y1_output_root_mean_squared_error: 1.2523 - val_y2_output_root_mean_squared_error: 1.9677
# Epoch 54/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.6779 - y1_output_loss: 1.2871 - y2_output_loss: 3.4124 - y1_output_root_mean_squared_error: 1.1342 - y2_output_root_mean_squared_error: 1.8416 - val_loss: 4.3744 - val_y1_output_loss: 1.2510 - val_y2_output_loss: 3.0024 - val_y1_output_root_mean_squared_error: 1.1312 - val_y2_output_root_mean_squared_error: 1.7592
# Epoch 55/500
# 614/614 [==============================] - 0s 132us/sample - loss: 4.4979 - y1_output_loss: 1.2301 - y2_output_loss: 3.2387 - y1_output_root_mean_squared_error: 1.1140 - y2_output_root_mean_squared_error: 1.8047 - val_loss: 4.2132 - val_y1_output_loss: 1.0602 - val_y2_output_loss: 3.0302 - val_y1_output_root_mean_squared_error: 1.0424 - val_y2_output_root_mean_squared_error: 1.7682
# Epoch 56/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.9173 - y1_output_loss: 1.0553 - y2_output_loss: 2.8336 - y1_output_root_mean_squared_error: 1.0321 - y2_output_root_mean_squared_error: 1.6888 - val_loss: 4.2386 - val_y1_output_loss: 1.2118 - val_y2_output_loss: 2.9282 - val_y1_output_root_mean_squared_error: 1.1160 - val_y2_output_root_mean_squared_error: 1.7301
# Epoch 57/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.5803 - y1_output_loss: 1.1892 - y2_output_loss: 3.4568 - y1_output_root_mean_squared_error: 1.0826 - y2_output_root_mean_squared_error: 1.8462 - val_loss: 17.5235 - val_y1_output_loss: 4.0767 - val_y2_output_loss: 13.1639 - val_y1_output_root_mean_squared_error: 2.0410 - val_y2_output_root_mean_squared_error: 3.6549
# Epoch 58/500
# 614/614 [==============================] - 0s 133us/sample - loss: 7.7042 - y1_output_loss: 2.1326 - y2_output_loss: 5.5216 - y1_output_root_mean_squared_error: 1.4633 - y2_output_root_mean_squared_error: 2.3586 - val_loss: 4.6342 - val_y1_output_loss: 1.6473 - val_y2_output_loss: 2.8778 - val_y1_output_root_mean_squared_error: 1.2920 - val_y2_output_root_mean_squared_error: 1.7219
# Epoch 59/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.3808 - y1_output_loss: 1.2329 - y2_output_loss: 3.1126 - y1_output_root_mean_squared_error: 1.1154 - y2_output_root_mean_squared_error: 1.7711 - val_loss: 4.9852 - val_y1_output_loss: 1.4153 - val_y2_output_loss: 3.4763 - val_y1_output_root_mean_squared_error: 1.1933 - val_y2_output_root_mean_squared_error: 1.8871
# Epoch 60/500
# 614/614 [==============================] - 0s 134us/sample - loss: 6.0128 - y1_output_loss: 1.5166 - y2_output_loss: 4.5101 - y1_output_root_mean_squared_error: 1.2315 - y2_output_root_mean_squared_error: 2.1204 - val_loss: 16.3482 - val_y1_output_loss: 6.4406 - val_y2_output_loss: 10.2188 - val_y1_output_root_mean_squared_error: 2.5043 - val_y2_output_root_mean_squared_error: 3.1743
# Epoch 61/500
# 614/614 [==============================] - 0s 140us/sample - loss: 5.1137 - y1_output_loss: 1.4163 - y2_output_loss: 3.6578 - y1_output_root_mean_squared_error: 1.1934 - y2_output_root_mean_squared_error: 1.9208 - val_loss: 3.7670 - val_y1_output_loss: 1.1173 - val_y2_output_loss: 2.5247 - val_y1_output_root_mean_squared_error: 1.0735 - val_y2_output_root_mean_squared_error: 1.6170
# Epoch 62/500
# 614/614 [==============================] - 0s 138us/sample - loss: 5.4412 - y1_output_loss: 1.5402 - y2_output_loss: 3.8668 - y1_output_root_mean_squared_error: 1.2453 - y2_output_root_mean_squared_error: 1.9724 - val_loss: 4.1902 - val_y1_output_loss: 1.1457 - val_y2_output_loss: 2.9857 - val_y1_output_root_mean_squared_error: 1.0722 - val_y2_output_root_mean_squared_error: 1.7437
# Epoch 63/500
# 614/614 [==============================] - 0s 149us/sample - loss: 4.0625 - y1_output_loss: 0.9068 - y2_output_loss: 3.1337 - y1_output_root_mean_squared_error: 0.9516 - y2_output_root_mean_squared_error: 1.7768 - val_loss: 4.4845 - val_y1_output_loss: 1.3317 - val_y2_output_loss: 2.9973 - val_y1_output_root_mean_squared_error: 1.1729 - val_y2_output_root_mean_squared_error: 1.7632
# Epoch 64/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.7771 - y1_output_loss: 0.9543 - y2_output_loss: 2.8131 - y1_output_root_mean_squared_error: 0.9715 - y2_output_root_mean_squared_error: 1.6833 - val_loss: 7.3316 - val_y1_output_loss: 1.6443 - val_y2_output_loss: 5.5927 - val_y1_output_root_mean_squared_error: 1.2850 - val_y2_output_root_mean_squared_error: 2.3833
# Epoch 65/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.8123 - y1_output_loss: 1.0171 - y2_output_loss: 2.8509 - y1_output_root_mean_squared_error: 1.0046 - y2_output_root_mean_squared_error: 1.6742 - val_loss: 11.1430 - val_y1_output_loss: 2.3101 - val_y2_output_loss: 8.9273 - val_y1_output_root_mean_squared_error: 1.4935 - val_y2_output_root_mean_squared_error: 2.9854
# Epoch 66/500
# 614/614 [==============================] - 0s 140us/sample - loss: 7.2368 - y1_output_loss: 1.8607 - y2_output_loss: 5.3506 - y1_output_root_mean_squared_error: 1.3603 - y2_output_root_mean_squared_error: 2.3208 - val_loss: 3.1870 - val_y1_output_loss: 0.9805 - val_y2_output_loss: 2.1183 - val_y1_output_root_mean_squared_error: 0.9985 - val_y2_output_root_mean_squared_error: 1.4799
# Epoch 67/500
# 614/614 [==============================] - 0s 138us/sample - loss: 4.5966 - y1_output_loss: 1.1285 - y2_output_loss: 3.4408 - y1_output_root_mean_squared_error: 1.0620 - y2_output_root_mean_squared_error: 1.8625 - val_loss: 4.0587 - val_y1_output_loss: 1.3255 - val_y2_output_loss: 2.6328 - val_y1_output_root_mean_squared_error: 1.1629 - val_y2_output_root_mean_squared_error: 1.6451
# Epoch 68/500
# 614/614 [==============================] - 0s 136us/sample - loss: 4.0921 - y1_output_loss: 1.0836 - y2_output_loss: 3.0489 - y1_output_root_mean_squared_error: 1.0372 - y2_output_root_mean_squared_error: 1.7368 - val_loss: 3.5708 - val_y1_output_loss: 1.1374 - val_y2_output_loss: 2.3129 - val_y1_output_root_mean_squared_error: 1.0818 - val_y2_output_root_mean_squared_error: 1.5493
# Epoch 69/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.8753 - y1_output_loss: 0.9897 - y2_output_loss: 2.8605 - y1_output_root_mean_squared_error: 0.9971 - y2_output_root_mean_squared_error: 1.6974 - val_loss: 3.4030 - val_y1_output_loss: 1.1721 - val_y2_output_loss: 2.1732 - val_y1_output_root_mean_squared_error: 1.0817 - val_y2_output_root_mean_squared_error: 1.4943
# Epoch 70/500
# 614/614 [==============================] - 0s 139us/sample - loss: 3.7378 - y1_output_loss: 0.9710 - y2_output_loss: 2.7598 - y1_output_root_mean_squared_error: 0.9863 - y2_output_root_mean_squared_error: 1.6628 - val_loss: 3.9153 - val_y1_output_loss: 0.6400 - val_y2_output_loss: 3.1594 - val_y1_output_root_mean_squared_error: 0.8115 - val_y2_output_root_mean_squared_error: 1.8046
# Epoch 71/500
# 614/614 [==============================] - 0s 138us/sample - loss: 4.0542 - y1_output_loss: 0.8728 - y2_output_loss: 3.1442 - y1_output_root_mean_squared_error: 0.9384 - y2_output_root_mean_squared_error: 1.7815 - val_loss: 2.8970 - val_y1_output_loss: 0.7240 - val_y2_output_loss: 2.0986 - val_y1_output_root_mean_squared_error: 0.8534 - val_y2_output_root_mean_squared_error: 1.4726
# Epoch 72/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.3317 - y1_output_loss: 1.0853 - y2_output_loss: 3.2381 - y1_output_root_mean_squared_error: 1.0457 - y2_output_root_mean_squared_error: 1.7995 - val_loss: 4.5831 - val_y1_output_loss: 1.0518 - val_y2_output_loss: 3.5065 - val_y1_output_root_mean_squared_error: 1.0228 - val_y2_output_root_mean_squared_error: 1.8807
# Epoch 73/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.7180 - y1_output_loss: 0.8840 - y2_output_loss: 2.8252 - y1_output_root_mean_squared_error: 0.9442 - y2_output_root_mean_squared_error: 1.6812 - val_loss: 3.1351 - val_y1_output_loss: 0.8070 - val_y2_output_loss: 2.2225 - val_y1_output_root_mean_squared_error: 0.9113 - val_y2_output_root_mean_squared_error: 1.5181
# Epoch 74/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.3493 - y1_output_loss: 0.8354 - y2_output_loss: 2.5340 - y1_output_root_mean_squared_error: 0.9170 - y2_output_root_mean_squared_error: 1.5838 - val_loss: 6.2423 - val_y1_output_loss: 1.8280 - val_y2_output_loss: 4.2567 - val_y1_output_root_mean_squared_error: 1.3668 - val_y2_output_root_mean_squared_error: 2.0914
# Epoch 75/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.1157 - y1_output_loss: 0.7536 - y2_output_loss: 2.3546 - y1_output_root_mean_squared_error: 0.8706 - y2_output_root_mean_squared_error: 1.5355 - val_loss: 10.3318 - val_y1_output_loss: 2.7164 - val_y2_output_loss: 7.7248 - val_y1_output_root_mean_squared_error: 1.6374 - val_y2_output_root_mean_squared_error: 2.7660
# Epoch 76/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.2372 - y1_output_loss: 0.9363 - y2_output_loss: 2.2918 - y1_output_root_mean_squared_error: 0.9671 - y2_output_root_mean_squared_error: 1.5172 - val_loss: 7.6726 - val_y1_output_loss: 1.6114 - val_y2_output_loss: 5.9053 - val_y1_output_root_mean_squared_error: 1.2819 - val_y2_output_root_mean_squared_error: 2.4554
# Epoch 77/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.9037 - y1_output_loss: 0.6433 - y2_output_loss: 2.2656 - y1_output_root_mean_squared_error: 0.7972 - y2_output_root_mean_squared_error: 1.5061 - val_loss: 2.5843 - val_y1_output_loss: 0.8193 - val_y2_output_loss: 1.6841 - val_y1_output_root_mean_squared_error: 0.9173 - val_y2_output_root_mean_squared_error: 1.3202
# Epoch 78/500
# 614/614 [==============================] - 0s 140us/sample - loss: 3.0434 - y1_output_loss: 0.6541 - y2_output_loss: 2.4136 - y1_output_root_mean_squared_error: 0.8054 - y2_output_root_mean_squared_error: 1.5475 - val_loss: 3.2391 - val_y1_output_loss: 0.8249 - val_y2_output_loss: 2.3147 - val_y1_output_root_mean_squared_error: 0.9196 - val_y2_output_root_mean_squared_error: 1.5471
# Epoch 79/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.6893 - y1_output_loss: 0.5826 - y2_output_loss: 2.0897 - y1_output_root_mean_squared_error: 0.7633 - y2_output_root_mean_squared_error: 1.4514 - val_loss: 2.7182 - val_y1_output_loss: 0.7685 - val_y2_output_loss: 1.9130 - val_y1_output_root_mean_squared_error: 0.8679 - val_y2_output_root_mean_squared_error: 1.4017
# Epoch 80/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.4153 - y1_output_loss: 0.7092 - y2_output_loss: 2.6993 - y1_output_root_mean_squared_error: 0.8437 - y2_output_root_mean_squared_error: 1.6442 - val_loss: 9.8168 - val_y1_output_loss: 1.9055 - val_y2_output_loss: 7.7660 - val_y1_output_root_mean_squared_error: 1.3990 - val_y2_output_root_mean_squared_error: 2.8035
# Epoch 81/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.3560 - y1_output_loss: 0.8974 - y2_output_loss: 2.5079 - y1_output_root_mean_squared_error: 0.9496 - y2_output_root_mean_squared_error: 1.5666 - val_loss: 9.0722 - val_y1_output_loss: 1.1678 - val_y2_output_loss: 7.8601 - val_y1_output_root_mean_squared_error: 1.0767 - val_y2_output_root_mean_squared_error: 2.8130
# Epoch 82/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.0264 - y1_output_loss: 0.9408 - y2_output_loss: 3.0756 - y1_output_root_mean_squared_error: 0.9724 - y2_output_root_mean_squared_error: 1.7552 - val_loss: 3.2368 - val_y1_output_loss: 0.5780 - val_y2_output_loss: 2.5897 - val_y1_output_root_mean_squared_error: 0.7669 - val_y2_output_root_mean_squared_error: 1.6275
# Epoch 83/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.0001 - y1_output_loss: 0.7023 - y2_output_loss: 2.2781 - y1_output_root_mean_squared_error: 0.8400 - y2_output_root_mean_squared_error: 1.5147 - val_loss: 2.8264 - val_y1_output_loss: 0.7655 - val_y2_output_loss: 2.0244 - val_y1_output_root_mean_squared_error: 0.8738 - val_y2_output_root_mean_squared_error: 1.4363
# Epoch 84/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.9276 - y1_output_loss: 0.6088 - y2_output_loss: 2.3406 - y1_output_root_mean_squared_error: 0.7796 - y2_output_root_mean_squared_error: 1.5231 - val_loss: 10.9453 - val_y1_output_loss: 1.6869 - val_y2_output_loss: 8.9573 - val_y1_output_root_mean_squared_error: 1.3169 - val_y2_output_root_mean_squared_error: 3.0350
# Epoch 85/500
# 614/614 [==============================] - 0s 139us/sample - loss: 4.0449 - y1_output_loss: 1.0123 - y2_output_loss: 3.0678 - y1_output_root_mean_squared_error: 1.0104 - y2_output_root_mean_squared_error: 1.7389 - val_loss: 5.7242 - val_y1_output_loss: 0.8422 - val_y2_output_loss: 4.7574 - val_y1_output_root_mean_squared_error: 0.9276 - val_y2_output_root_mean_squared_error: 2.2054
# Epoch 86/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.7684 - y1_output_loss: 0.5587 - y2_output_loss: 2.2011 - y1_output_root_mean_squared_error: 0.7503 - y2_output_root_mean_squared_error: 1.4851 - val_loss: 3.5487 - val_y1_output_loss: 0.4609 - val_y2_output_loss: 2.9920 - val_y1_output_root_mean_squared_error: 0.6885 - val_y2_output_root_mean_squared_error: 1.7535
# Epoch 87/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.1728 - y1_output_loss: 0.8176 - y2_output_loss: 2.3339 - y1_output_root_mean_squared_error: 0.9043 - y2_output_root_mean_squared_error: 1.5346 - val_loss: 2.6027 - val_y1_output_loss: 0.7496 - val_y2_output_loss: 1.8371 - val_y1_output_root_mean_squared_error: 0.8533 - val_y2_output_root_mean_squared_error: 1.3692
# Epoch 88/500
# 614/614 [==============================] - 0s 157us/sample - loss: 2.7926 - y1_output_loss: 0.5795 - y2_output_loss: 2.1875 - y1_output_root_mean_squared_error: 0.7648 - y2_output_root_mean_squared_error: 1.4858 - val_loss: 2.2149 - val_y1_output_loss: 0.5176 - val_y2_output_loss: 1.6441 - val_y1_output_root_mean_squared_error: 0.7167 - val_y2_output_root_mean_squared_error: 1.3043
# Epoch 89/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.9824 - y1_output_loss: 0.7869 - y2_output_loss: 2.1981 - y1_output_root_mean_squared_error: 0.8804 - y2_output_root_mean_squared_error: 1.4857 - val_loss: 3.2194 - val_y1_output_loss: 1.0952 - val_y2_output_loss: 2.0320 - val_y1_output_root_mean_squared_error: 1.0600 - val_y2_output_root_mean_squared_error: 1.4476
# Epoch 90/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.3281 - y1_output_loss: 0.5120 - y2_output_loss: 1.8059 - y1_output_root_mean_squared_error: 0.7139 - y2_output_root_mean_squared_error: 1.3485 - val_loss: 2.7211 - val_y1_output_loss: 0.5463 - val_y2_output_loss: 2.0891 - val_y1_output_root_mean_squared_error: 0.7488 - val_y2_output_root_mean_squared_error: 1.4698
# Epoch 91/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.6582 - y1_output_loss: 0.5851 - y2_output_loss: 2.0606 - y1_output_root_mean_squared_error: 0.7637 - y2_output_root_mean_squared_error: 1.4405 - val_loss: 2.8262 - val_y1_output_loss: 0.6788 - val_y2_output_loss: 2.0781 - val_y1_output_root_mean_squared_error: 0.8294 - val_y2_output_root_mean_squared_error: 1.4623
# Epoch 92/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.3562 - y1_output_loss: 0.4770 - y2_output_loss: 1.8669 - y1_output_root_mean_squared_error: 0.6921 - y2_output_root_mean_squared_error: 1.3701 - val_loss: 2.4036 - val_y1_output_loss: 0.8095 - val_y2_output_loss: 1.5481 - val_y1_output_root_mean_squared_error: 0.8995 - val_y2_output_root_mean_squared_error: 1.2628
# Epoch 93/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.1023 - y1_output_loss: 0.4657 - y2_output_loss: 1.6371 - y1_output_root_mean_squared_error: 0.6817 - y2_output_root_mean_squared_error: 1.2797 - val_loss: 4.3270 - val_y1_output_loss: 0.9590 - val_y2_output_loss: 3.3540 - val_y1_output_root_mean_squared_error: 0.9666 - val_y2_output_root_mean_squared_error: 1.8419
# Epoch 94/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.7058 - y1_output_loss: 0.6231 - y2_output_loss: 2.0642 - y1_output_root_mean_squared_error: 0.7916 - y2_output_root_mean_squared_error: 1.4419 - val_loss: 2.1975 - val_y1_output_loss: 0.4411 - val_y2_output_loss: 1.6823 - val_y1_output_root_mean_squared_error: 0.6739 - val_y2_output_root_mean_squared_error: 1.3204
# Epoch 95/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.6133 - y1_output_loss: 0.5623 - y2_output_loss: 2.0439 - y1_output_root_mean_squared_error: 0.7479 - y2_output_root_mean_squared_error: 1.4332 - val_loss: 3.2653 - val_y1_output_loss: 0.5562 - val_y2_output_loss: 2.6566 - val_y1_output_root_mean_squared_error: 0.7577 - val_y2_output_root_mean_squared_error: 1.6405
# Epoch 96/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.1652 - y1_output_loss: 0.5274 - y2_output_loss: 1.6427 - y1_output_root_mean_squared_error: 0.7271 - y2_output_root_mean_squared_error: 1.2793 - val_loss: 6.1905 - val_y1_output_loss: 0.9039 - val_y2_output_loss: 5.1735 - val_y1_output_root_mean_squared_error: 0.9492 - val_y2_output_root_mean_squared_error: 2.2999
# Epoch 97/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.3079 - y1_output_loss: 0.5197 - y2_output_loss: 1.7880 - y1_output_root_mean_squared_error: 0.7235 - y2_output_root_mean_squared_error: 1.3358 - val_loss: 4.1152 - val_y1_output_loss: 0.6280 - val_y2_output_loss: 3.3803 - val_y1_output_root_mean_squared_error: 0.8047 - val_y2_output_root_mean_squared_error: 1.8622
# Epoch 98/500
# 614/614 [==============================] - 0s 162us/sample - loss: 2.2402 - y1_output_loss: 0.5640 - y2_output_loss: 1.6560 - y1_output_root_mean_squared_error: 0.7543 - y2_output_root_mean_squared_error: 1.2928 - val_loss: 2.9442 - val_y1_output_loss: 0.7405 - val_y2_output_loss: 2.1308 - val_y1_output_root_mean_squared_error: 0.8633 - val_y2_output_root_mean_squared_error: 1.4829
# Epoch 99/500
# 614/614 [==============================] - 0s 139us/sample - loss: 2.5500 - y1_output_loss: 0.5960 - y2_output_loss: 1.9438 - y1_output_root_mean_squared_error: 0.7746 - y2_output_root_mean_squared_error: 1.3964 - val_loss: 6.9612 - val_y1_output_loss: 1.1866 - val_y2_output_loss: 5.5726 - val_y1_output_root_mean_squared_error: 1.1057 - val_y2_output_root_mean_squared_error: 2.3955
# Epoch 100/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.2144 - y1_output_loss: 0.4882 - y2_output_loss: 1.7231 - y1_output_root_mean_squared_error: 0.6964 - y2_output_root_mean_squared_error: 1.3150 - val_loss: 3.2241 - val_y1_output_loss: 0.7356 - val_y2_output_loss: 2.4659 - val_y1_output_root_mean_squared_error: 0.8516 - val_y2_output_root_mean_squared_error: 1.5808
# Epoch 101/500
# 614/614 [==============================] - 0s 137us/sample - loss: 4.4339 - y1_output_loss: 1.0860 - y2_output_loss: 3.3074 - y1_output_root_mean_squared_error: 1.0469 - y2_output_root_mean_squared_error: 1.8270 - val_loss: 2.2152 - val_y1_output_loss: 0.5543 - val_y2_output_loss: 1.6064 - val_y1_output_root_mean_squared_error: 0.7494 - val_y2_output_root_mean_squared_error: 1.2859
# Epoch 102/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.6472 - y1_output_loss: 0.5824 - y2_output_loss: 2.0677 - y1_output_root_mean_squared_error: 0.7633 - y2_output_root_mean_squared_error: 1.4368 - val_loss: 4.3114 - val_y1_output_loss: 1.2589 - val_y2_output_loss: 3.1199 - val_y1_output_root_mean_squared_error: 1.0982 - val_y2_output_root_mean_squared_error: 1.7622
# Epoch 103/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.0750 - y1_output_loss: 0.8634 - y2_output_loss: 2.1982 - y1_output_root_mean_squared_error: 0.9329 - y2_output_root_mean_squared_error: 1.4848 - val_loss: 2.1771 - val_y1_output_loss: 0.5987 - val_y2_output_loss: 1.5309 - val_y1_output_root_mean_squared_error: 0.7787 - val_y2_output_root_mean_squared_error: 1.2533
# Epoch 104/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.3455 - y1_output_loss: 0.5268 - y2_output_loss: 1.9777 - y1_output_root_mean_squared_error: 0.7253 - y2_output_root_mean_squared_error: 1.3489 - val_loss: 53.5331 - val_y1_output_loss: 7.6183 - val_y2_output_loss: 46.2525 - val_y1_output_root_mean_squared_error: 2.7359 - val_y2_output_root_mean_squared_error: 6.7858
# Epoch 105/500
# 614/614 [==============================] - 0s 141us/sample - loss: 5.4762 - y1_output_loss: 1.2886 - y2_output_loss: 4.1435 - y1_output_root_mean_squared_error: 1.1394 - y2_output_root_mean_squared_error: 2.0440 - val_loss: 3.2763 - val_y1_output_loss: 0.5751 - val_y2_output_loss: 2.6892 - val_y1_output_root_mean_squared_error: 0.7585 - val_y2_output_root_mean_squared_error: 1.6435
# Epoch 106/500
# 614/614 [==============================] - 0s 153us/sample - loss: 2.2187 - y1_output_loss: 0.5123 - y2_output_loss: 1.6938 - y1_output_root_mean_squared_error: 0.7189 - y2_output_root_mean_squared_error: 1.3045 - val_loss: 2.1736 - val_y1_output_loss: 0.4200 - val_y2_output_loss: 1.6858 - val_y1_output_root_mean_squared_error: 0.6578 - val_y2_output_root_mean_squared_error: 1.3195
# Epoch 107/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.8951 - y1_output_loss: 0.6343 - y2_output_loss: 2.2363 - y1_output_root_mean_squared_error: 0.7994 - y2_output_root_mean_squared_error: 1.5020 - val_loss: 2.8060 - val_y1_output_loss: 0.9183 - val_y2_output_loss: 1.8614 - val_y1_output_root_mean_squared_error: 0.9508 - val_y2_output_root_mean_squared_error: 1.3791
# Epoch 108/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.3857 - y1_output_loss: 0.4872 - y2_output_loss: 1.8863 - y1_output_root_mean_squared_error: 0.7005 - y2_output_root_mean_squared_error: 1.3766 - val_loss: 2.1933 - val_y1_output_loss: 0.5710 - val_y2_output_loss: 1.5603 - val_y1_output_root_mean_squared_error: 0.7620 - val_y2_output_root_mean_squared_error: 1.2699
# Epoch 109/500
# 614/614 [==============================] - 0s 148us/sample - loss: 1.7548 - y1_output_loss: 0.4493 - y2_output_loss: 1.3052 - y1_output_root_mean_squared_error: 0.6734 - y2_output_root_mean_squared_error: 1.1408 - val_loss: 1.8207 - val_y1_output_loss: 0.4112 - val_y2_output_loss: 1.3527 - val_y1_output_root_mean_squared_error: 0.6490 - val_y2_output_root_mean_squared_error: 1.1830
# Epoch 110/500
# 614/614 [==============================] - 0s 143us/sample - loss: 2.0982 - y1_output_loss: 0.4893 - y2_output_loss: 1.6071 - y1_output_root_mean_squared_error: 0.6998 - y2_output_root_mean_squared_error: 1.2682 - val_loss: 4.6812 - val_y1_output_loss: 1.0328 - val_y2_output_loss: 3.5303 - val_y1_output_root_mean_squared_error: 1.0266 - val_y2_output_root_mean_squared_error: 1.9045
# Epoch 111/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.7265 - y1_output_loss: 0.6175 - y2_output_loss: 2.1134 - y1_output_root_mean_squared_error: 0.7861 - y2_output_root_mean_squared_error: 1.4521 - val_loss: 2.6937 - val_y1_output_loss: 0.5750 - val_y2_output_loss: 2.0497 - val_y1_output_root_mean_squared_error: 0.7670 - val_y2_output_root_mean_squared_error: 1.4510
# Epoch 112/500
# 614/614 [==============================] - 0s 146us/sample - loss: 2.1126 - y1_output_loss: 0.4907 - y2_output_loss: 1.6295 - y1_output_root_mean_squared_error: 0.7024 - y2_output_root_mean_squared_error: 1.2725 - val_loss: 2.2359 - val_y1_output_loss: 0.3712 - val_y2_output_loss: 1.8110 - val_y1_output_root_mean_squared_error: 0.6160 - val_y2_output_root_mean_squared_error: 1.3625
# Epoch 113/500
# 614/614 [==============================] - 0s 138us/sample - loss: 1.9786 - y1_output_loss: 0.4289 - y2_output_loss: 1.5535 - y1_output_root_mean_squared_error: 0.6564 - y2_output_root_mean_squared_error: 1.2441 - val_loss: 3.0845 - val_y1_output_loss: 0.8066 - val_y2_output_loss: 2.2929 - val_y1_output_root_mean_squared_error: 0.8843 - val_y2_output_root_mean_squared_error: 1.5174
# Epoch 114/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.0278 - y1_output_loss: 0.4866 - y2_output_loss: 1.5566 - y1_output_root_mean_squared_error: 0.6945 - y2_output_root_mean_squared_error: 1.2431 - val_loss: 6.1661 - val_y1_output_loss: 1.4545 - val_y2_output_loss: 4.6387 - val_y1_output_root_mean_squared_error: 1.2107 - val_y2_output_root_mean_squared_error: 2.1680
# Epoch 115/500
# 614/614 [==============================] - 0s 133us/sample - loss: 1.7219 - y1_output_loss: 0.3755 - y2_output_loss: 1.3871 - y1_output_root_mean_squared_error: 0.6125 - y2_output_root_mean_squared_error: 1.1605 - val_loss: 5.4013 - val_y1_output_loss: 1.0157 - val_y2_output_loss: 4.4009 - val_y1_output_root_mean_squared_error: 0.9957 - val_y2_output_root_mean_squared_error: 2.1000
# Epoch 116/500
# 614/614 [==============================] - 0s 134us/sample - loss: 1.9946 - y1_output_loss: 0.4161 - y2_output_loss: 1.5741 - y1_output_root_mean_squared_error: 0.6448 - y2_output_root_mean_squared_error: 1.2565 - val_loss: 2.0792 - val_y1_output_loss: 0.4720 - val_y2_output_loss: 1.5338 - val_y1_output_root_mean_squared_error: 0.6977 - val_y2_output_root_mean_squared_error: 1.2619
# Epoch 117/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.7465 - y1_output_loss: 0.7695 - y2_output_loss: 1.9588 - y1_output_root_mean_squared_error: 0.8810 - y2_output_root_mean_squared_error: 1.4037 - val_loss: 2.5943 - val_y1_output_loss: 0.6502 - val_y2_output_loss: 1.8921 - val_y1_output_root_mean_squared_error: 0.7961 - val_y2_output_root_mean_squared_error: 1.4002
# Epoch 118/500
# 614/614 [==============================] - 0s 141us/sample - loss: 1.7798 - y1_output_loss: 0.4078 - y2_output_loss: 1.3879 - y1_output_root_mean_squared_error: 0.6351 - y2_output_root_mean_squared_error: 1.1732 - val_loss: 8.2438 - val_y1_output_loss: 1.6450 - val_y2_output_loss: 6.3527 - val_y1_output_root_mean_squared_error: 1.3049 - val_y2_output_root_mean_squared_error: 2.5575
# Epoch 119/500
# 614/614 [==============================] - 0s 140us/sample - loss: 1.6426 - y1_output_loss: 0.3714 - y2_output_loss: 1.2601 - y1_output_root_mean_squared_error: 0.6096 - y2_output_root_mean_squared_error: 1.1274 - val_loss: 1.8569 - val_y1_output_loss: 0.3457 - val_y2_output_loss: 1.4548 - val_y1_output_root_mean_squared_error: 0.5963 - val_y2_output_root_mean_squared_error: 1.2253
# Epoch 120/500
# 614/614 [==============================] - 0s 152us/sample - loss: 2.6344 - y1_output_loss: 0.5454 - y2_output_loss: 2.0649 - y1_output_root_mean_squared_error: 0.7420 - y2_output_root_mean_squared_error: 1.4436 - val_loss: 1.9954 - val_y1_output_loss: 0.4492 - val_y2_output_loss: 1.4984 - val_y1_output_root_mean_squared_error: 0.6778 - val_y2_output_root_mean_squared_error: 1.2393
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.3575 - y1_output_loss: 0.1144 - y2_output_loss: 0.2430 - y1_output_root_mean_squared_error: 0.3368 - y2_output_root_mean_squared_error: 0.4940 - val_loss: 1.1796 - val_y1_output_loss: 0.2764 - val_y2_output_loss: 0.9200 - val_y1_output_root_mean_squared_error: 0.5265 - val_y2_output_root_mean_squared_error: 0.9499
# Epoch 462/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.7703 - y1_output_loss: 0.1929 - y2_output_loss: 0.6002 - y1_output_root_mean_squared_error: 0.4353 - y2_output_root_mean_squared_error: 0.7622 - val_loss: 1.7364 - val_y1_output_loss: 0.2754 - val_y2_output_loss: 1.4394 - val_y1_output_root_mean_squared_error: 0.5270 - val_y2_output_root_mean_squared_error: 1.2078
# Epoch 463/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.3939 - y1_output_loss: 0.1182 - y2_output_loss: 0.2733 - y1_output_root_mean_squared_error: 0.3443 - y2_output_root_mean_squared_error: 0.5248 - val_loss: 0.7452 - val_y1_output_loss: 0.1556 - val_y2_output_loss: 0.5732 - val_y1_output_root_mean_squared_error: 0.3997 - val_y2_output_root_mean_squared_error: 0.7651
# Epoch 464/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.3461 - y1_output_loss: 0.1236 - y2_output_loss: 0.2304 - y1_output_root_mean_squared_error: 0.3511 - y2_output_root_mean_squared_error: 0.4720 - val_loss: 1.6605 - val_y1_output_loss: 0.2455 - val_y2_output_loss: 1.3917 - val_y1_output_root_mean_squared_error: 0.5025 - val_y2_output_root_mean_squared_error: 1.1866
# Epoch 465/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.6520 - y1_output_loss: 0.1574 - y2_output_loss: 0.5030 - y1_output_root_mean_squared_error: 0.3959 - y2_output_root_mean_squared_error: 0.7037 - val_loss: 2.2170 - val_y1_output_loss: 0.3879 - val_y2_output_loss: 1.7562 - val_y1_output_root_mean_squared_error: 0.6342 - val_y2_output_root_mean_squared_error: 1.3471
# Epoch 466/500
# 614/614 [==============================] - 0s 164us/sample - loss: 0.3831 - y1_output_loss: 0.1191 - y2_output_loss: 0.2659 - y1_output_root_mean_squared_error: 0.3467 - y2_output_root_mean_squared_error: 0.5128 - val_loss: 1.1591 - val_y1_output_loss: 0.3233 - val_y2_output_loss: 0.8269 - val_y1_output_root_mean_squared_error: 0.5597 - val_y2_output_root_mean_squared_error: 0.9197
# Epoch 467/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3985 - y1_output_loss: 0.1243 - y2_output_loss: 0.2758 - y1_output_root_mean_squared_error: 0.3524 - y2_output_root_mean_squared_error: 0.5237 - val_loss: 1.0629 - val_y1_output_loss: 0.2471 - val_y2_output_loss: 0.7915 - val_y1_output_root_mean_squared_error: 0.5056 - val_y2_output_root_mean_squared_error: 0.8985
# Epoch 468/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.4488 - y1_output_loss: 0.1385 - y2_output_loss: 0.3071 - y1_output_root_mean_squared_error: 0.3735 - y2_output_root_mean_squared_error: 0.5561 - val_loss: 0.7593 - val_y1_output_loss: 0.1848 - val_y2_output_loss: 0.5554 - val_y1_output_root_mean_squared_error: 0.4360 - val_y2_output_root_mean_squared_error: 0.7545
# Epoch 469/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3198 - y1_output_loss: 0.1047 - y2_output_loss: 0.2194 - y1_output_root_mean_squared_error: 0.3240 - y2_output_root_mean_squared_error: 0.4635 - val_loss: 2.7363 - val_y1_output_loss: 0.4029 - val_y2_output_loss: 2.3109 - val_y1_output_root_mean_squared_error: 0.6274 - val_y2_output_root_mean_squared_error: 1.5306
# Epoch 470/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.7011 - y1_output_loss: 0.2058 - y2_output_loss: 0.4959 - y1_output_root_mean_squared_error: 0.4540 - y2_output_root_mean_squared_error: 0.7036 - val_loss: 2.3632 - val_y1_output_loss: 0.3268 - val_y2_output_loss: 2.0457 - val_y1_output_root_mean_squared_error: 0.5752 - val_y2_output_root_mean_squared_error: 1.4256
# Epoch 471/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.3936 - y1_output_loss: 0.1119 - y2_output_loss: 0.2843 - y1_output_root_mean_squared_error: 0.3354 - y2_output_root_mean_squared_error: 0.5301 - val_loss: 1.0797 - val_y1_output_loss: 0.1890 - val_y2_output_loss: 0.8786 - val_y1_output_root_mean_squared_error: 0.4403 - val_y2_output_root_mean_squared_error: 0.9412
# Epoch 472/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3477 - y1_output_loss: 0.1006 - y2_output_loss: 0.2450 - y1_output_root_mean_squared_error: 0.3179 - y2_output_root_mean_squared_error: 0.4966 - val_loss: 0.7749 - val_y1_output_loss: 0.1804 - val_y2_output_loss: 0.5801 - val_y1_output_root_mean_squared_error: 0.4304 - val_y2_output_root_mean_squared_error: 0.7679
# Epoch 473/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.2936 - y1_output_loss: 0.0946 - y2_output_loss: 0.1975 - y1_output_root_mean_squared_error: 0.3086 - y2_output_root_mean_squared_error: 0.4454 - val_loss: 0.7450 - val_y1_output_loss: 0.1660 - val_y2_output_loss: 0.5595 - val_y1_output_root_mean_squared_error: 0.4119 - val_y2_output_root_mean_squared_error: 0.7585
# Epoch 474/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3573 - y1_output_loss: 0.1147 - y2_output_loss: 0.2406 - y1_output_root_mean_squared_error: 0.3396 - y2_output_root_mean_squared_error: 0.4919 - val_loss: 1.0524 - val_y1_output_loss: 0.2231 - val_y2_output_loss: 0.8108 - val_y1_output_root_mean_squared_error: 0.4795 - val_y2_output_root_mean_squared_error: 0.9069
# Epoch 475/500
# 614/614 [==============================] - 0s 166us/sample - loss: 0.3015 - y1_output_loss: 0.1042 - y2_output_loss: 0.1979 - y1_output_root_mean_squared_error: 0.3215 - y2_output_root_mean_squared_error: 0.4452 - val_loss: 1.0905 - val_y1_output_loss: 0.2369 - val_y2_output_loss: 0.8358 - val_y1_output_root_mean_squared_error: 0.4916 - val_y2_output_root_mean_squared_error: 0.9213
# Epoch 476/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.2653 - y1_output_loss: 0.0863 - y2_output_loss: 0.1784 - y1_output_root_mean_squared_error: 0.2944 - y2_output_root_mean_squared_error: 0.4226 - val_loss: 0.7258 - val_y1_output_loss: 0.1743 - val_y2_output_loss: 0.5350 - val_y1_output_root_mean_squared_error: 0.4217 - val_y2_output_root_mean_squared_error: 0.7403
# Epoch 477/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3012 - y1_output_loss: 0.1063 - y2_output_loss: 0.1950 - y1_output_root_mean_squared_error: 0.3249 - y2_output_root_mean_squared_error: 0.4424 - val_loss: 0.9654 - val_y1_output_loss: 0.2522 - val_y2_output_loss: 0.6940 - val_y1_output_root_mean_squared_error: 0.5107 - val_y2_output_root_mean_squared_error: 0.8394
# Epoch 478/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3991 - y1_output_loss: 0.1201 - y2_output_loss: 0.2963 - y1_output_root_mean_squared_error: 0.3379 - y2_output_root_mean_squared_error: 0.5338 - val_loss: 3.0927 - val_y1_output_loss: 0.8927 - val_y2_output_loss: 2.2378 - val_y1_output_root_mean_squared_error: 0.9480 - val_y2_output_root_mean_squared_error: 1.4812
# Epoch 479/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3562 - y1_output_loss: 0.1217 - y2_output_loss: 0.2374 - y1_output_root_mean_squared_error: 0.3456 - y2_output_root_mean_squared_error: 0.4866 - val_loss: 1.4887 - val_y1_output_loss: 0.5022 - val_y2_output_loss: 0.9913 - val_y1_output_root_mean_squared_error: 0.6929 - val_y2_output_root_mean_squared_error: 1.0043
# Epoch 480/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.4430 - y1_output_loss: 0.1407 - y2_output_loss: 0.2995 - y1_output_root_mean_squared_error: 0.3765 - y2_output_root_mean_squared_error: 0.5489 - val_loss: 0.7961 - val_y1_output_loss: 0.1881 - val_y2_output_loss: 0.5902 - val_y1_output_root_mean_squared_error: 0.4337 - val_y2_output_root_mean_squared_error: 0.7798
# Epoch 481/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.4711 - y1_output_loss: 0.1522 - y2_output_loss: 0.3176 - y1_output_root_mean_squared_error: 0.3913 - y2_output_root_mean_squared_error: 0.5639 - val_loss: 1.0600 - val_y1_output_loss: 0.2163 - val_y2_output_loss: 0.8150 - val_y1_output_root_mean_squared_error: 0.4724 - val_y2_output_root_mean_squared_error: 0.9148
# Epoch 482/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.3814 - y1_output_loss: 0.1228 - y2_output_loss: 0.2618 - y1_output_root_mean_squared_error: 0.3482 - y2_output_root_mean_squared_error: 0.5100 - val_loss: 0.9206 - val_y1_output_loss: 0.1671 - val_y2_output_loss: 0.7368 - val_y1_output_root_mean_squared_error: 0.4158 - val_y2_output_root_mean_squared_error: 0.8647
# Epoch 483/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3657 - y1_output_loss: 0.1129 - y2_output_loss: 0.2504 - y1_output_root_mean_squared_error: 0.3368 - y2_output_root_mean_squared_error: 0.5023 - val_loss: 0.7394 - val_y1_output_loss: 0.1677 - val_y2_output_loss: 0.5591 - val_y1_output_root_mean_squared_error: 0.4142 - val_y2_output_root_mean_squared_error: 0.7536
# Epoch 484/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.3151 - y1_output_loss: 0.1037 - y2_output_loss: 0.2184 - y1_output_root_mean_squared_error: 0.3130 - y2_output_root_mean_squared_error: 0.4660 - val_loss: 0.9004 - val_y1_output_loss: 0.3302 - val_y2_output_loss: 0.5638 - val_y1_output_root_mean_squared_error: 0.5747 - val_y2_output_root_mean_squared_error: 0.7551
# Epoch 485/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.3186 - y1_output_loss: 0.1112 - y2_output_loss: 0.2077 - y1_output_root_mean_squared_error: 0.3321 - y2_output_root_mean_squared_error: 0.4564 - val_loss: 1.0000 - val_y1_output_loss: 0.2191 - val_y2_output_loss: 0.7634 - val_y1_output_root_mean_squared_error: 0.4741 - val_y2_output_root_mean_squared_error: 0.8804
# Epoch 486/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3610 - y1_output_loss: 0.1164 - y2_output_loss: 0.2431 - y1_output_root_mean_squared_error: 0.3410 - y2_output_root_mean_squared_error: 0.4947 - val_loss: 1.0377 - val_y1_output_loss: 0.2321 - val_y2_output_loss: 0.7834 - val_y1_output_root_mean_squared_error: 0.4832 - val_y2_output_root_mean_squared_error: 0.8968
# Epoch 487/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3963 - y1_output_loss: 0.1255 - y2_output_loss: 0.2700 - y1_output_root_mean_squared_error: 0.3551 - y2_output_root_mean_squared_error: 0.5198 - val_loss: 0.7664 - val_y1_output_loss: 0.1615 - val_y2_output_loss: 0.5838 - val_y1_output_root_mean_squared_error: 0.4077 - val_y2_output_root_mean_squared_error: 0.7747
# Epoch 488/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3018 - y1_output_loss: 0.0968 - y2_output_loss: 0.2028 - y1_output_root_mean_squared_error: 0.3122 - y2_output_root_mean_squared_error: 0.4520 - val_loss: 0.9270 - val_y1_output_loss: 0.2547 - val_y2_output_loss: 0.6524 - val_y1_output_root_mean_squared_error: 0.5035 - val_y2_output_root_mean_squared_error: 0.8207
# Epoch 489/500
# 614/614 [==============================] - 0s 141us/sample - loss: 1.2965 - y1_output_loss: 0.2735 - y2_output_loss: 1.0114 - y1_output_root_mean_squared_error: 0.5252 - y2_output_root_mean_squared_error: 1.0103 - val_loss: 0.9964 - val_y1_output_loss: 0.1938 - val_y2_output_loss: 0.7891 - val_y1_output_root_mean_squared_error: 0.4461 - val_y2_output_root_mean_squared_error: 0.8930
# Epoch 490/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3800 - y1_output_loss: 0.1244 - y2_output_loss: 0.2539 - y1_output_root_mean_squared_error: 0.3539 - y2_output_root_mean_squared_error: 0.5047 - val_loss: 0.8612 - val_y1_output_loss: 0.1627 - val_y2_output_loss: 0.6742 - val_y1_output_root_mean_squared_error: 0.4091 - val_y2_output_root_mean_squared_error: 0.8329
# Epoch 491/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.4550 - y1_output_loss: 0.1293 - y2_output_loss: 0.3235 - y1_output_root_mean_squared_error: 0.3596 - y2_output_root_mean_squared_error: 0.5707 - val_loss: 0.7713 - val_y1_output_loss: 0.1543 - val_y2_output_loss: 0.5971 - val_y1_output_root_mean_squared_error: 0.3993 - val_y2_output_root_mean_squared_error: 0.7822
# Epoch 492/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.2855 - y1_output_loss: 0.1084 - y2_output_loss: 0.1779 - y1_output_root_mean_squared_error: 0.3288 - y2_output_root_mean_squared_error: 0.4212 - val_loss: 1.2993 - val_y1_output_loss: 0.2864 - val_y2_output_loss: 1.0350 - val_y1_output_root_mean_squared_error: 0.5350 - val_y2_output_root_mean_squared_error: 1.0065
# Epoch 493/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.4899 - y1_output_loss: 0.1524 - y2_output_loss: 0.3329 - y1_output_root_mean_squared_error: 0.3922 - y2_output_root_mean_squared_error: 0.5797 - val_loss: 0.7136 - val_y1_output_loss: 0.1658 - val_y2_output_loss: 0.5322 - val_y1_output_root_mean_squared_error: 0.4128 - val_y2_output_root_mean_squared_error: 0.7370
# Epoch 494/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3288 - y1_output_loss: 0.1237 - y2_output_loss: 0.2036 - y1_output_root_mean_squared_error: 0.3529 - y2_output_root_mean_squared_error: 0.4520 - val_loss: 0.8708 - val_y1_output_loss: 0.1752 - val_y2_output_loss: 0.6729 - val_y1_output_root_mean_squared_error: 0.4221 - val_y2_output_root_mean_squared_error: 0.8323
# Epoch 495/500
# 614/614 [==============================] - 0s 179us/sample - loss: 0.3411 - y1_output_loss: 0.0989 - y2_output_loss: 0.2416 - y1_output_root_mean_squared_error: 0.3153 - y2_output_root_mean_squared_error: 0.4916 - val_loss: 0.9052 - val_y1_output_loss: 0.1817 - val_y2_output_loss: 0.6949 - val_y1_output_root_mean_squared_error: 0.4326 - val_y2_output_root_mean_squared_error: 0.8474
# Epoch 496/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.4525 - y1_output_loss: 0.1348 - y2_output_loss: 0.3143 - y1_output_root_mean_squared_error: 0.3677 - y2_output_root_mean_squared_error: 0.5633 - val_loss: 0.7005 - val_y1_output_loss: 0.1716 - val_y2_output_loss: 0.5134 - val_y1_output_root_mean_squared_error: 0.4193 - val_y2_output_root_mean_squared_error: 0.7244
# Epoch 497/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3142 - y1_output_loss: 0.1074 - y2_output_loss: 0.2045 - y1_output_root_mean_squared_error: 0.3290 - y2_output_root_mean_squared_error: 0.4539 - val_loss: 0.7615 - val_y1_output_loss: 0.1811 - val_y2_output_loss: 0.5591 - val_y1_output_root_mean_squared_error: 0.4297 - val_y2_output_root_mean_squared_error: 0.7595
# Epoch 498/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.2679 - y1_output_loss: 0.0932 - y2_output_loss: 0.1728 - y1_output_root_mean_squared_error: 0.3060 - y2_output_root_mean_squared_error: 0.4175 - val_loss: 0.8377 - val_y1_output_loss: 0.2008 - val_y2_output_loss: 0.6251 - val_y1_output_root_mean_squared_error: 0.4544 - val_y2_output_root_mean_squared_error: 0.7945
# Epoch 499/500
# 614/614 [==============================] - 0s 167us/sample - loss: 0.2990 - y1_output_loss: 0.0979 - y2_output_loss: 0.2022 - y1_output_root_mean_squared_error: 0.3127 - y2_output_root_mean_squared_error: 0.4486 - val_loss: 0.7473 - val_y1_output_loss: 0.1524 - val_y2_output_loss: 0.5732 - val_y1_output_root_mean_squared_error: 0.3960 - val_y2_output_root_mean_squared_error: 0.7684
# Epoch 500/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.3134 - y1_output_loss: 0.1011 - y2_output_loss: 0.2106 - y1_output_root_mean_squared_error: 0.3183 - y2_output_root_mean_squared_error: 0.4606 - val_loss: 0.6999 - val_y1_output_loss: 0.1678 - val_y2_output_loss: 0.5158 - val_y1_output_root_mean_squared_error: 0.4155 - val_y2_output_root_mean_squared_error: 0.7261

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 40us/sample - loss: 0.6999 - y1_output_loss: 0.1693 - y2_output_loss: 0.5305 - y1_output_root_mean_squared_error: 0.4155 - y2_output_root_mean_squared_error: 0.7261
# Loss = 0.6999377221256108, Y1_loss = 0.1693456918001175, Y1_mse = 0.4155253469944, Y2_loss = 0.5305212736129761, Y2_mse = 0.7261379957199097

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
