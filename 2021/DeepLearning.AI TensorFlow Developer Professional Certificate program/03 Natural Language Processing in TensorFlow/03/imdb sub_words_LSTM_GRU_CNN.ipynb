# %%
import tensorflow as tf
import tensorflow_datasets as tfds

imdb, info = tfds.load("imdb_reviews/subwords8k", with_info=True, as_supervised=True)
# Out:
# WARNING:absl:Warning: Setting shuffle_files=True because split=TRAIN and shuffle_files=None. This behavior will be deprecated on 2019-08-06, at which point shuffle_files=False will be the default for all splits.

# %%
train_data, test_data = imdb['train'], imdb['test']

# %%
tokenizer = info.features['text'].encoder

# %%
BUFFER_SIZE = 10000
BATCH_SIZE = 64

train_dataset = train_data.shuffle(BUFFER_SIZE)
train_dataset = train_dataset.padded_batch(BATCH_SIZE, tf.compat.v1.data.get_output_shapes(train_dataset))
test_dataset = test_data.padded_batch(BATCH_SIZE, tf.compat.v1.data.get_output_shapes(test_data))

# %% [markdown]
# ### LSTM

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(tokenizer.vocab_size, 64),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, None, 64)          523840
# _________________________________________________________________
# bidirectional (Bidirectional (None, None, 128)         66048
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 64)                41216
# _________________________________________________________________
# dense (Dense)                (None, 64)                4160
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 635,329
# Trainable params: 635,329
# Non-trainable params: 0
# _________________________________________________________________

# %%
num_epochs = 10

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

history = model.fit(train_dataset, epochs=num_epochs, validation_data=test_dataset)
# Out:
# Epoch 1/10
# 391/391 [==============================] - 87s 222ms/step - loss: 0.6001 - accuracy: 0.6711 - val_loss: 0.6921 - val_accuracy: 0.5926
# Epoch 2/10
# 391/391 [==============================] - 86s 220ms/step - loss: 0.5196 - accuracy: 0.7491 - val_loss: 0.4999 - val_accuracy: 0.7684
# Epoch 3/10
# 391/391 [==============================] - 86s 220ms/step - loss: 0.3439 - accuracy: 0.8580 - val_loss: 0.3645 - val_accuracy: 0.8538
# Epoch 4/10
# 391/391 [==============================] - 86s 219ms/step - loss: 0.2424 - accuracy: 0.9072 - val_loss: 0.3439 - val_accuracy: 0.8638
# Epoch 5/10
# 391/391 [==============================] - 85s 219ms/step - loss: 0.1868 - accuracy: 0.9326 - val_loss: 0.3175 - val_accuracy: 0.8732
# Epoch 6/10
# 391/391 [==============================] - 85s 216ms/step - loss: 0.1409 - accuracy: 0.9520 - val_loss: 0.3478 - val_accuracy: 0.8691
# Epoch 7/10
# 391/391 [==============================] - 86s 219ms/step - loss: 0.1014 - accuracy: 0.9672 - val_loss: 0.3952 - val_accuracy: 0.8680
# Epoch 8/10
# 391/391 [==============================] - 86s 220ms/step - loss: 0.0764 - accuracy: 0.9770 - val_loss: 0.4772 - val_accuracy: 0.8524
# Epoch 9/10
# 391/391 [==============================] - 86s 220ms/step - loss: 0.0608 - accuracy: 0.9824 - val_loss: 0.5172 - val_accuracy: 0.8585
# Epoch 10/10
# 391/391 [==============================] - 87s 222ms/step - loss: 0.0496 - accuracy: 0.9864 - val_loss: 0.5267 - val_accuracy: 0.8669

# %%
import matplotlib.pyplot as plt


def plot_graphs(history, string):
    plt.plot(history.history[string])
    plt.plot(history.history['val_'+string])
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.legend([string, 'val_'+string])
    plt.show()

# %%
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

# overfitting
# LSTM

# %% [markdown]
# ### Only Embedding

# %%
embedding_dim = 16
max_length = 120

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(tokenizer.vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 120, 16)           130960
# _________________________________________________________________
# dense (Dense)                (None, 120, 64)           1088
# _________________________________________________________________
# dense_1 (Dense)              (None, 120, 1)            65
# =================================================================
# Total params: 132,113
# Trainable params: 132,113
# Non-trainable params: 0
# _________________________________________________________________

# %%
num_epochs = 10

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

history = model.fit(train_dataset, epochs=num_epochs, validation_data=test_dataset)
# Out:
# Epoch 1/10
# 391/391 [==============================] - 4s 10ms/step - loss: 0.6919 - accuracy: 0.5087 - val_loss: 0.6916 - val_accuracy: 0.5107
# Epoch 2/10
# 391/391 [==============================] - 4s 10ms/step - loss: 0.6908 - accuracy: 0.5113 - val_loss: 0.6910 - val_accuracy: 0.5113
# Epoch 3/10
# 391/391 [==============================] - 4s 10ms/step - loss: 0.6906 - accuracy: 0.5104 - val_loss: 0.6911 - val_accuracy: 0.5113
# Epoch 4/10
# 391/391 [==============================] - 4s 10ms/step - loss: 0.6906 - accuracy: 0.5132 - val_loss: 0.6911 - val_accuracy: 0.5113
# Epoch 5/10
# 391/391 [==============================] - 4s 10ms/step - loss: 0.6906 - accuracy: 0.5132 - val_loss: 0.6911 - val_accuracy: 0.5105
# Epoch 6/10
# 391/391 [==============================] - 4s 10ms/step - loss: 0.6905 - accuracy: 0.5133 - val_loss: 0.6911 - val_accuracy: 0.5113
# Epoch 7/10
# 391/391 [==============================] - 4s 10ms/step - loss: 0.6906 - accuracy: 0.5142 - val_loss: 0.6912 - val_accuracy: 0.5112
# Epoch 8/10
# 391/391 [==============================] - 4s 10ms/step - loss: 0.6906 - accuracy: 0.5097 - val_loss: 0.6910 - val_accuracy: 0.5113
# Epoch 9/10
# 391/391 [==============================] - 4s 10ms/step - loss: 0.6905 - accuracy: 0.5130 - val_loss: 0.6912 - val_accuracy: 0.5113
# Epoch 10/10
# 391/391 [==============================] - 4s 10ms/step - loss: 0.6905 - accuracy: 0.5155 - val_loss: 0.6911 - val_accuracy: 0.5107

# %%
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

# overfitting

# %% [markdown]
# ### GRU

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(tokenizer.vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Bidirectional(tf.keras.layers.GRU(32)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.summary()

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

history = model.fit(train_dataset, epochs=num_epochs, validation_data=test_dataset)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 120, 16)           130960
# _________________________________________________________________
# bidirectional (Bidirectional (None, 64)                9600
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 144,785
# Trainable params: 144,785
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 391/391 [==============================] - 44s 112ms/step - loss: 0.5609 - accuracy: 0.6816 - val_loss: 0.4222 - val_accuracy: 0.8158
# Epoch 2/10
# 391/391 [==============================] - 43s 111ms/step - loss: 0.3171 - accuracy: 0.8717 - val_loss: 0.3575 - val_accuracy: 0.8525
# Epoch 3/10
# 391/391 [==============================] - 43s 111ms/step - loss: 0.2448 - accuracy: 0.9076 - val_loss: 0.3754 - val_accuracy: 0.8620
# Epoch 4/10
# 391/391 [==============================] - 43s 110ms/step - loss: 0.1957 - accuracy: 0.9305 - val_loss: 0.3796 - val_accuracy: 0.8547
# Epoch 5/10
# 391/391 [==============================] - 43s 111ms/step - loss: 0.1589 - accuracy: 0.9444 - val_loss: 0.4026 - val_accuracy: 0.8494
# Epoch 6/10
# 391/391 [==============================] - 43s 111ms/step - loss: 0.1401 - accuracy: 0.9514 - val_loss: 0.4789 - val_accuracy: 0.8538
# Epoch 7/10
# 391/391 [==============================] - 43s 110ms/step - loss: 0.1180 - accuracy: 0.9601 - val_loss: 0.4678 - val_accuracy: 0.8439
# Epoch 8/10
# 391/391 [==============================] - 43s 110ms/step - loss: 0.0986 - accuracy: 0.9659 - val_loss: 0.5177 - val_accuracy: 0.8470
# Epoch 9/10
# 391/391 [==============================] - 43s 111ms/step - loss: 0.0924 - accuracy: 0.9689 - val_loss: 0.5114 - val_accuracy: 0.8390
# Epoch 10/10
# 391/391 [==============================] - 43s 111ms/step - loss: 0.0746 - accuracy: 0.9764 - val_loss: 0.5734 - val_accuracy: 0.8519

# %%
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

# overfitting

# %% [markdown]
# ### CNN

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(tokenizer.vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Conv1D(128, 5, activation='relu'),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.summary()

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

history = model.fit(train_dataset, epochs=num_epochs, validation_data=test_dataset)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 120, 16)           130960
# _________________________________________________________________
# conv1d (Conv1D)              (None, 116, 128)          10368
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 128)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 149,649
# Trainable params: 149,649
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 391/391 [==============================] - 10s 24ms/step - loss: 0.5062 - accuracy: 0.7295 - val_loss: 0.3290 - val_accuracy: 0.8687
# Epoch 2/10
# 391/391 [==============================] - 6s 15ms/step - loss: 0.2475 - accuracy: 0.9064 - val_loss: 0.3000 - val_accuracy: 0.8790
# Epoch 3/10
# 391/391 [==============================] - 5s 13ms/step - loss: 0.1883 - accuracy: 0.9332 - val_loss: 0.3148 - val_accuracy: 0.8754
# Epoch 4/10
# 391/391 [==============================] - 5s 13ms/step - loss: 0.1534 - accuracy: 0.9450 - val_loss: 0.3374 - val_accuracy: 0.8728
# Epoch 5/10
# 391/391 [==============================] - 5s 13ms/step - loss: 0.1302 - accuracy: 0.9561 - val_loss: 0.3788 - val_accuracy: 0.8637
# Epoch 6/10
# 391/391 [==============================] - 5s 13ms/step - loss: 0.1096 - accuracy: 0.9626 - val_loss: 0.4392 - val_accuracy: 0.8629
# Epoch 7/10
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0922 - accuracy: 0.9706 - val_loss: 0.4916 - val_accuracy: 0.8606
# Epoch 8/10
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0760 - accuracy: 0.9765 - val_loss: 0.5910 - val_accuracy: 0.8528
# Epoch 9/10
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0665 - accuracy: 0.9798 - val_loss: 0.6384 - val_accuracy: 0.8535
# Epoch 10/10
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0555 - accuracy: 0.9843 - val_loss: 0.6710 - val_accuracy: 0.8516

# %%
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

# overfitting
