# %%
import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
path = "../../Data/BigContest/Baseball data/csv file/"

data1 = pd.read_csv(path+"2020빅콘테스트_스포츠투아이_제공데이터_경기_2016.csv", encoding="CP949")
data2 = pd.read_csv(path+"2020빅콘테스트_스포츠투아이_제공데이터_경기_2017.csv", encoding="CP949")
data3 = pd.read_csv(path+"2020빅콘테스트_스포츠투아이_제공데이터_경기_2018.csv", encoding="CP949")
data4 = pd.read_csv(path+"2020빅콘테스트_스포츠투아이_제공데이터_경기_2019.csv", encoding="CP949")

# %%
data1.head(30)
# Out:
#              G_ID   GDAY_DS VISIT_KEY HOME_KEY  HEADER_NO GWEEK STADIUM
# 0   20160401HHLG0  20160401        HH       LG          0     금      잠실
# 1   20160401HTNC0  20160401        HT       NC          0     금      마산
# 2   20160401KTSK0  20160401        KT       SK          0     금      문학
# 3   20160401LTWO0  20160401        LT       WO          0     금      고척
# 4   20160401OBSS0  20160401        OB       SS          0     금      대구
# 5   20160402HHLG0  20160402        HH       LG          0     토      잠실
# 6   20160402HTNC0  20160402        HT       NC          0     토      마산
# 7   20160402KTSK0  20160402        KT       SK          0     토      문학
# 8   20160402LTWO0  20160402        LT       WO          0     토      고척
# 9   20160402OBSS0  20160402        OB       SS          0     토      대구
# 10  20160403KTSK0  20160403        KT       SK          0     일      문학
# 11  20160403LTWO0  20160403        LT       WO          0     일      고척
# ...
