# %% [markdown]
# ## Import Package

# %%
import numpy as np


import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator 

import os

# %% [markdown]
# ## Data Import

# %%
path = '../../../data/intel_image_classification/'

path_training = path + 'seg_train/seg_train/' # traininng set
path_valid = path + 'seg_test/seg_test/' # vaildation set
path_pred = path + 'seg_pred/seg_pred/' # prediction set

# labels
labels = os.listdir(path_training) # os.listdir(path_valid)

# %% [markdown]
# ### Import Training/Valid Data + Image Generator

# %%
print("Training")
for label in labels:
    print(f'  {label}: {len(os.listdir(path_training+label))}')
    
print()

print("Validation")
for label in labels:
    print(f'  {label}: {len(os.listdir(path_valid+label))}')
# Out:
# Training
#   forest: 2271
#   mountain: 2512
#   street: 2382
#   sea: 2274
#   glacier: 2404
#   buildings: 2191
#
# Validation
#   forest: 474
#   mountain: 525
#   street: 501
#   sea: 510
#   glacier: 553
#   buildings: 437

# %%
train_datagen = ImageDataGenerator(rescale = 1./255)
train_generator = train_datagen.flow_from_directory(path_training,
                                                  target_size=(150,150),
                                                  batch_size=20,
                                                  color_mode='rgb')
"""

                                                  width_shift_range=0.2,
                                                  height_shift_range=0.2,
                                                  shear_range=0.2,
                                                  zoom_range=0.2,
                                                  fill_mode='nearest',
                                                  class_mode='cagegorical'
"""


valid_datagen = ImageDataGenerator(rescale = 1./255)
test_generator = valid_datagen.flow_from_directory(path_valid,
                                                  target_size=(150,150))
# Out:
# Found 14034 images belonging to 6 classes.
# Found 3000 images belonging to 6 classes.

# %%
from tensorflow.keras.layers import Layer

# %%
class IdentityBlock(tf.keras.Model):
    def __init__(self, filters, kernel_size):
        super(IdentityBlock, self).__init__(name='')
        
        self.conv1 = tf.keras.layers.Conv2D(filters, kernel_size, padding='same')
        self.bn1 = tf.keras.layers.BatchNormalization()
        
        self.conv2 = tf.keras.layers.Conv2D(filters, kernel_size, padding='same')
        self.bn2 = tf.keras.layers.BatchNormalization()
        
        self.act = tf.keras.layers.Activation('relu')
        self.add = tf.keras.layers.Add()
        
    def call(self, input_tensor):
        X = self.conv1(input_tensor)
        X = self.bn1(X)
        X = self.act(X)
        
        X = self.conv2(X)
        X = self.bn2(X)
        
        X = self.add([X, input_tensor])
        X = self.act(X)
        return X
    
class ResNet(tf.keras.Model):
    def __init__(self, num_classes):
        super(ResNet, self).__init__()
        self.conv = tf.keras.layers.Conv2D(64, 7, padding='same')
        self.bn = tf.keras.layers.BatchNormalization()
        self.act = tf.keras.layers.Activation('relu')
        self.max_pool = tf.keras.layers.MaxPool2D((3, 3))

        # Use the Identity blocks that you just defined
        self.id1a = IdentityBlock(64, 3)
        self.id1b = IdentityBlock(64, 3)

        self.global_pool = tf.keras.layers.GlobalAveragePooling2D()
        
        self.flatten = tf.keras.layers.Flatten()
        self.drop = tf.keras.layers.Dropout(0.4)
        self.dense_1 = tf.keras.layers.Dense(1024, activation='sigmoid')
        self.dense_2 = tf.keras.layers.Dense(512, activation='sigmoid')
        self.classifier = tf.keras.layers.Dense(num_classes, activation='sigmoid')

    def call(self, inputs):
        x = self.conv(inputs)
        x = self.bn(x)
        x = self.act(x)
        x = self.max_pool(x)

        # insert the identity blocks in the middle of the network
        x = self.id1a(x)
        x = self.id1b(x)
        x = self.global_pool(x)
        
        x = self.flatten(x)
        x = self.drop(x)
        x = self.dense_1(x)
        x = self.dense_2(x)
        
        return self.classifier(x)

# %%
resnet = ResNet(len(labels))

# %%
resnet.compile(optimizer=tf.keras.optimizers.Adam(lr=0.0001),
               loss=tf.keras.losses.CategoricalCrossentropy(),
               metrics=['accuracy'])
# Out:
# /home/jaewon/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:374: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(

# %%
history = resnet.fit(train_generator,
           epochs=100,
           validation_data=test_generator)
# Out:
# Epoch 1/100
# 702/702 [==============================] - 21s 30ms/step - loss: 1.1234 - accuracy: 0.5223 - val_loss: 1.1700 - val_accuracy: 0.5063
# Epoch 2/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.8920 - accuracy: 0.6308 - val_loss: 0.8014 - val_accuracy: 0.6843
# Epoch 3/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.8285 - accuracy: 0.6640 - val_loss: 0.7983 - val_accuracy: 0.6873
# Epoch 4/100
# 702/702 [==============================] - 20s 28ms/step - loss: 0.7919 - accuracy: 0.6863 - val_loss: 0.7664 - val_accuracy: 0.6953
# Epoch 5/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.7386 - accuracy: 0.7086 - val_loss: 0.8764 - val_accuracy: 0.6470
# Epoch 6/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.7255 - accuracy: 0.7178 - val_loss: 1.2778 - val_accuracy: 0.5897
# Epoch 7/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.6964 - accuracy: 0.7323 - val_loss: 0.8680 - val_accuracy: 0.6687
# Epoch 8/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.6679 - accuracy: 0.7455 - val_loss: 0.8292 - val_accuracy: 0.6743
# Epoch 9/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.6430 - accuracy: 0.7510 - val_loss: 0.6590 - val_accuracy: 0.7380
# Epoch 10/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.6370 - accuracy: 0.7566 - val_loss: 1.9189 - val_accuracy: 0.3620
# Epoch 11/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.6217 - accuracy: 0.7669 - val_loss: 0.9561 - val_accuracy: 0.6137
# Epoch 12/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.5953 - accuracy: 0.7706 - val_loss: 0.8017 - val_accuracy: 0.7093
# Epoch 13/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.5971 - accuracy: 0.7716 - val_loss: 0.5436 - val_accuracy: 0.7863
# Epoch 14/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.5773 - accuracy: 0.7830 - val_loss: 0.5870 - val_accuracy: 0.7800
# Epoch 15/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.5622 - accuracy: 0.7872 - val_loss: 1.1532 - val_accuracy: 0.5970
# Epoch 16/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.5613 - accuracy: 0.7875 - val_loss: 0.6422 - val_accuracy: 0.7373
# Epoch 17/100
# 702/702 [==============================] - 21s 29ms/step - loss: 0.5396 - accuracy: 0.7961 - val_loss: 0.8241 - val_accuracy: 0.6613
# Epoch 18/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.5393 - accuracy: 0.7978 - val_loss: 0.6537 - val_accuracy: 0.7457
# Epoch 19/100
# 702/702 [==============================] - 21s 29ms/step - loss: 0.5225 - accuracy: 0.8077 - val_loss: 0.5841 - val_accuracy: 0.7867
# Epoch 20/100
# 702/702 [==============================] - 21s 29ms/step - loss: 0.5150 - accuracy: 0.8072 - val_loss: 0.7895 - val_accuracy: 0.7213
# Epoch 21/100
# 702/702 [==============================] - 21s 29ms/step - loss: 0.5044 - accuracy: 0.8113 - val_loss: 0.9086 - val_accuracy: 0.7107
# Epoch 22/100
# 702/702 [==============================] - 21s 29ms/step - loss: 0.5051 - accuracy: 0.8117 - val_loss: 1.7860 - val_accuracy: 0.5543
# Epoch 23/100
# 702/702 [==============================] - 21s 29ms/step - loss: 0.4987 - accuracy: 0.8125 - val_loss: 0.4889 - val_accuracy: 0.8270
# Epoch 24/100
# 702/702 [==============================] - 21s 29ms/step - loss: 0.4889 - accuracy: 0.8231 - val_loss: 0.9023 - val_accuracy: 0.6567
# Epoch 25/100
# 702/702 [==============================] - 21s 29ms/step - loss: 0.4893 - accuracy: 0.8180 - val_loss: 0.7385 - val_accuracy: 0.7183
# Epoch 26/100
# 702/702 [==============================] - 21s 29ms/step - loss: 0.4730 - accuracy: 0.8254 - val_loss: 0.5667 - val_accuracy: 0.7983
# Epoch 27/100
# 702/702 [==============================] - 21s 29ms/step - loss: 0.4762 - accuracy: 0.8244 - val_loss: 0.4156 - val_accuracy: 0.8487
# Epoch 28/100
# 702/702 [==============================] - 21s 29ms/step - loss: 0.4708 - accuracy: 0.8286 - val_loss: 1.4482 - val_accuracy: 0.5593
# Epoch 29/100
# 702/702 [==============================] - 21s 29ms/step - loss: 0.4637 - accuracy: 0.8306 - val_loss: 0.4963 - val_accuracy: 0.8220
# Epoch 30/100
# 702/702 [==============================] - 21s 29ms/step - loss: 0.4539 - accuracy: 0.8323 - val_loss: 0.7286 - val_accuracy: 0.7493
# Epoch 31/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.4585 - accuracy: 0.8293 - val_loss: 0.4661 - val_accuracy: 0.8180
# Epoch 32/100
# 702/702 [==============================] - 21s 29ms/step - loss: 0.4530 - accuracy: 0.8333 - val_loss: 1.8221 - val_accuracy: 0.5293
# Epoch 33/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.4441 - accuracy: 0.8413 - val_loss: 0.6600 - val_accuracy: 0.7550
# Epoch 34/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.4428 - accuracy: 0.8406 - val_loss: 0.4224 - val_accuracy: 0.8413
# Epoch 35/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.4353 - accuracy: 0.8410 - val_loss: 1.4349 - val_accuracy: 0.5073
# Epoch 36/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.4250 - accuracy: 0.8452 - val_loss: 1.0370 - val_accuracy: 0.6570
# Epoch 37/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.4306 - accuracy: 0.8410 - val_loss: 1.3872 - val_accuracy: 0.6413
# Epoch 38/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.4291 - accuracy: 0.8424 - val_loss: 0.6030 - val_accuracy: 0.7810
# Epoch 39/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.4240 - accuracy: 0.8447 - val_loss: 0.4220 - val_accuracy: 0.8493
# Epoch 40/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.4076 - accuracy: 0.8525 - val_loss: 0.5463 - val_accuracy: 0.7793
# Epoch 41/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.4068 - accuracy: 0.8501 - val_loss: 0.4511 - val_accuracy: 0.8277
# Epoch 42/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.4094 - accuracy: 0.8499 - val_loss: 0.9705 - val_accuracy: 0.6280
# Epoch 43/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.4080 - accuracy: 0.8488 - val_loss: 0.4675 - val_accuracy: 0.8253
# Epoch 44/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.3993 - accuracy: 0.8538 - val_loss: 0.4090 - val_accuracy: 0.8527
# Epoch 45/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.3939 - accuracy: 0.8547 - val_loss: 0.8830 - val_accuracy: 0.6790
# Epoch 46/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.4022 - accuracy: 0.8524 - val_loss: 0.5255 - val_accuracy: 0.8060
# Epoch 47/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.3929 - accuracy: 0.8562 - val_loss: 0.4397 - val_accuracy: 0.8383
# Epoch 48/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.3871 - accuracy: 0.8598 - val_loss: 0.6648 - val_accuracy: 0.7490
# Epoch 49/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.3918 - accuracy: 0.8573 - val_loss: 0.4190 - val_accuracy: 0.8403
# Epoch 50/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.3769 - accuracy: 0.8625 - val_loss: 0.5104 - val_accuracy: 0.8190
# Epoch 51/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.3877 - accuracy: 0.8588 - val_loss: 0.6153 - val_accuracy: 0.7887
# Epoch 52/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.3820 - accuracy: 0.8613 - val_loss: 0.3988 - val_accuracy: 0.8527
# Epoch 53/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.3736 - accuracy: 0.8658 - val_loss: 0.5285 - val_accuracy: 0.8130
# Epoch 54/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.3718 - accuracy: 0.8625 - val_loss: 0.5905 - val_accuracy: 0.7883
# Epoch 55/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.3588 - accuracy: 0.8685 - val_loss: 0.6121 - val_accuracy: 0.7810
# Epoch 56/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.3652 - accuracy: 0.8696 - val_loss: 0.4350 - val_accuracy: 0.8417
# Epoch 57/100
# 702/702 [==============================] - 20s 28ms/step - loss: 0.3640 - accuracy: 0.8710 - val_loss: 0.4930 - val_accuracy: 0.8283
# Epoch 58/100
# 702/702 [==============================] - 20s 28ms/step - loss: 0.3632 - accuracy: 0.8708 - val_loss: 0.3823 - val_accuracy: 0.8593
# Epoch 59/100
# 702/702 [==============================] - 20s 28ms/step - loss: 0.3682 - accuracy: 0.8682 - val_loss: 0.3860 - val_accuracy: 0.8570
# Epoch 60/100
# 702/702 [==============================] - 20s 28ms/step - loss: 0.3562 - accuracy: 0.8720 - val_loss: 0.5079 - val_accuracy: 0.7883
# Epoch 61/100
# 702/702 [==============================] - 20s 28ms/step - loss: 0.3567 - accuracy: 0.8697 - val_loss: 0.3451 - val_accuracy: 0.8790
# Epoch 62/100
# 702/702 [==============================] - 20s 28ms/step - loss: 0.3586 - accuracy: 0.8706 - val_loss: 0.3776 - val_accuracy: 0.8613
# Epoch 63/100
# 702/702 [==============================] - 20s 28ms/step - loss: 0.3573 - accuracy: 0.8673 - val_loss: 0.5895 - val_accuracy: 0.7813
# Epoch 64/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.3541 - accuracy: 0.8690 - val_loss: 0.6156 - val_accuracy: 0.7933
# Epoch 65/100
# 702/702 [==============================] - 20s 28ms/step - loss: 0.3476 - accuracy: 0.8730 - val_loss: 0.4228 - val_accuracy: 0.8503
# Epoch 66/100
# 702/702 [==============================] - 20s 28ms/step - loss: 0.3425 - accuracy: 0.8752 - val_loss: 0.6213 - val_accuracy: 0.7923
# Epoch 67/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.3450 - accuracy: 0.8761 - val_loss: 0.5786 - val_accuracy: 0.7840
# Epoch 68/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.3430 - accuracy: 0.8756 - val_loss: 0.7503 - val_accuracy: 0.7350
# Epoch 69/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.3378 - accuracy: 0.8786 - val_loss: 0.8256 - val_accuracy: 0.7270
# Epoch 70/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.3358 - accuracy: 0.8799 - val_loss: 0.5914 - val_accuracy: 0.7950
# Epoch 71/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.3337 - accuracy: 0.8823 - val_loss: 0.4132 - val_accuracy: 0.8587
# Epoch 72/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.3288 - accuracy: 0.8809 - val_loss: 0.5199 - val_accuracy: 0.7907
# Epoch 73/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.3324 - accuracy: 0.8747 - val_loss: 0.4143 - val_accuracy: 0.8513
# Epoch 74/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.3254 - accuracy: 0.8834 - val_loss: 0.5198 - val_accuracy: 0.8077
# Epoch 75/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.3318 - accuracy: 0.8792 - val_loss: 0.9139 - val_accuracy: 0.7067
# Epoch 76/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.3242 - accuracy: 0.8834 - val_loss: 0.5590 - val_accuracy: 0.7840
# Epoch 77/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.3283 - accuracy: 0.8795 - val_loss: 1.4822 - val_accuracy: 0.5970
# Epoch 78/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.3226 - accuracy: 0.8831 - val_loss: 0.3392 - val_accuracy: 0.8743
# Epoch 79/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.3142 - accuracy: 0.8864 - val_loss: 0.3240 - val_accuracy: 0.8813
# Epoch 80/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.3190 - accuracy: 0.8850 - val_loss: 0.4763 - val_accuracy: 0.8270
# Epoch 81/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.3187 - accuracy: 0.8859 - val_loss: 0.4166 - val_accuracy: 0.8487
# Epoch 82/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.3192 - accuracy: 0.8858 - val_loss: 0.4934 - val_accuracy: 0.8237
# Epoch 83/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.3166 - accuracy: 0.8863 - val_loss: 0.5402 - val_accuracy: 0.8217
# Epoch 84/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.3077 - accuracy: 0.8883 - val_loss: 0.3957 - val_accuracy: 0.8550
# Epoch 85/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.3140 - accuracy: 0.8853 - val_loss: 0.3555 - val_accuracy: 0.8680
# Epoch 86/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.3020 - accuracy: 0.8918 - val_loss: 0.7755 - val_accuracy: 0.7623
# Epoch 87/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.3138 - accuracy: 0.8870 - val_loss: 0.9213 - val_accuracy: 0.7313
# Epoch 88/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.3098 - accuracy: 0.8884 - val_loss: 0.4257 - val_accuracy: 0.8467
# Epoch 89/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.3063 - accuracy: 0.8920 - val_loss: 0.4432 - val_accuracy: 0.8487
# Epoch 90/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.3090 - accuracy: 0.8906 - val_loss: 0.4446 - val_accuracy: 0.8277
# Epoch 91/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.2993 - accuracy: 0.8909 - val_loss: 0.4270 - val_accuracy: 0.8517
# Epoch 92/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.2952 - accuracy: 0.8942 - val_loss: 0.5323 - val_accuracy: 0.8107
# Epoch 93/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.3000 - accuracy: 0.8918 - val_loss: 0.3619 - val_accuracy: 0.8703
# Epoch 94/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.2981 - accuracy: 0.8918 - val_loss: 0.3154 - val_accuracy: 0.8853
# Epoch 95/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.2923 - accuracy: 0.8945 - val_loss: 0.3222 - val_accuracy: 0.8847
# Epoch 96/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.2997 - accuracy: 0.8909 - val_loss: 0.3661 - val_accuracy: 0.8697
# Epoch 97/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.2955 - accuracy: 0.8953 - val_loss: 0.4726 - val_accuracy: 0.8363
# Epoch 98/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.2930 - accuracy: 0.8935 - val_loss: 0.4788 - val_accuracy: 0.8100
# Epoch 99/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.2900 - accuracy: 0.8955 - val_loss: 0.3739 - val_accuracy: 0.8717
# Epoch 100/100
# 702/702 [==============================] - 20s 29ms/step - loss: 0.2908 - accuracy: 0.8950 - val_loss: 0.4524 - val_accuracy: 0.8283

# %%
import matplotlib.pyplot as plt

def plot_graphs(history, string):
    plt.plot(history.history[string])
    plt.plot(history.history['val_'+string])
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.legend([string, 'val_'+string])
    plt.show()
    
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

# %%
# Plot the chart for accuracy and loss on both training and validation
# %matplotlib inline
import matplotlib.pyplot as plt
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()

plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
print("Accuracy:", history.history['accuracy'][-1])
print("Validation Accuracy:", history.history['val_accuracy'][-1])
# Out:
# Accuracy: 0.8950406312942505
# Validation Accuracy: 0.82833331823349
