# %%
import pandas as pd
import numpy as np

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
model = keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
yx = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# y = 2x-1

# %%
model.fit(xs, yx, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.5645
# Epoch 2/500
# 1/1 [==============================] - 0s 820us/step - loss: 0.5518
# Epoch 3/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.5395
# Epoch 4/500
# 1/1 [==============================] - 0s 695us/step - loss: 0.5277
# Epoch 5/500
# 1/1 [==============================] - 0s 452us/step - loss: 0.5163
# Epoch 6/500
# 1/1 [==============================] - 0s 520us/step - loss: 0.5053
# Epoch 7/500
# 1/1 [==============================] - 0s 557us/step - loss: 0.4946
# Epoch 8/500
# 1/1 [==============================] - 0s 711us/step - loss: 0.4841
# Epoch 9/500
# 1/1 [==============================] - 0s 502us/step - loss: 0.4740
# Epoch 10/500
# 1/1 [==============================] - 0s 407us/step - loss: 0.4641
# Epoch 11/500
# 1/1 [==============================] - 0s 659us/step - loss: 0.4544
# Epoch 12/500
# ...

# %%
print(model.predict([10.0]))

# x=10 -> y=19
# Out:
# [[18.987707]]

# %%
# model shows only close value, why?
# 1. trained it using very little data
# 2. it is linear, but there is no guarantee that the graph will be linear for every x-value (probability)
